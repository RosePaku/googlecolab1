# %%
2+3

# 주석 = ctrl + /
# 명령어 실행
# 1. ctrl + enter = 해당 셸에 머물러 있음
# 2. alt + enter = 새로운 셸을 만들어 이동 (수업할 때)
# 3. shift + enter = 다음 셸로 이동 (복습 용도)

# 문제 1
print("Hello Python " * 3)

# 문제 2
print("혼자 공부하다 모르면 동영상 강의를 참고하세요!")

# 표현식
273
52
10+20
"Hello"
# import

# 문장
print("Hello")
# 문장이 모이면 프로그램

#  키워드 확인
import keyword
print(keyword.kwlist)
# Out:
# Hello Python Hello Python Hello Python
# 혼자 공부하다 모르면 동영상 강의를 참고하세요!
# Hello
# ['False', 'None', 'True', '__peg_parser__', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
# 하나만 출력
print("ㄱㄴㄷ")
print()
# 여러 개 출력
print("ㄱㄴㄷ","ㄱㄴㄷ1","ㄱㄴㄷ2")
print()
# 단순하게 줄바꿈
print("====")
print()
print()
print("====")
# Out:
# ㄱㄴㄷ
#
# ㄱㄴㄷ ㄱㄴㄷ1 ㄱㄴㄷ2
#
# ====
#
#
# ====

# %% [markdown]
# # 자료형

# %% [markdown]
# ##중제목

# %%
# 자료형 확인
type(24)
# int = integer = 정수

type(2.4)
# float = 실수
# str = string = 문자


# 한번에 표기
print(type(24))
print(type(2.4))
print(type("안녕"))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
# 문자열
print("안녕")
print('안녕')
# Out:
# 안녕
# 안녕

# %%
print(""안녕"이라고 말해봐") # 에러
# Out:
#   File "<ipython-input-29-31e359782b1c>", line 1
#     print(""안녕"이라고 말해봐") # 에러
#             ^
# SyntaxError: invalid syntax

# %%
print('"안녕"이라고 말해봐')
# Out:
# "안녕"이라고 말해봐

# %%
print(''배고파'라고 말해봐') # 에러
# Out:
#   File "<ipython-input-33-9e96c3614458>", line 1
#     print(''배고파'이라고 말해봐') #에러
#             ^
# SyntaxError: invalid syntax

# %%
print("'배고파'라고 말해봐")
# Out:
# '배고파'라고 말해봐

# %%
# 이스케이프문자
print("\"안녕\"이라고 말해봐") # 큰따옴표만 쓰는 경우 
print("'배고파'라고 말해봐")# 작은따옴표만 쓰는 경우
# Out:
# "안녕"이라고 말해봐
# '배고파'라고 말해봐

# %%
# 줄바꿈
print("안녕\n안녕")

# 탭
print("안녕\t안녕")
# Out:
# 안녕
# 안녕
# 안녕	안녕

# %%
# 역슬래시
print('\\ \\')
# Out:
# \ \

# %%
# 여러줄 문자열
print("동해물과\n하느님이\n무궁화\n대한으로")
# Out:
# 동해물과
# 하느님이
# 무궁화
# 대한으로

# %%
print("""동해물과
하느님이
무궁화
대한으로""")
# Out:
# 동해물과
# 하느님이
# 무궁화
# 대한으로

# %%
print("""
동해물과
하느님이
무궁화
대한으로
""")
# Out:
# 동해물과
# 하느님이
# 무궁화
# 대한으로

# %%
print("""\
동해물과
하느님이
무궁화
대한으로\
""")
# Out:
# 동해물과
# 하느님이
# 무궁화
# 대한으로

# %%
# 문자열 연산자
print("안녕"+"하삼")
# Out:
# 안녕하삼

# %%
print("안녕"+1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-beef7f99b592> in <module>
# ----> 1 print("안녕"+1)
#
# TypeError: can only concatenate str (not "int") to str

# %%
print("안녕"+"1")
print("안녕"+"!")
# Out:
# 안녕1
# 안녕!

# %%
# 문자열 반복 연산자
print("안녕"*4)
# Out:
# 안녕안녕안녕안녕

# %%
print(4*"안녕")
# Out:
# 안녕안녕안녕안녕

# %%
print("안녕하세요"[0])
print("안녕하세요"[1])
print("안녕하세요"[2])
print("안녕하세요"[3])
print("안녕하세요"[4])
print("안녕하세요"[5])
# 파이썬은 인덱싱을 할 때 0부터 시작한다 0을 1로 취급
# Out:
# 안
# 녕
# 하
# 세
# 요
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-64-a43910282bc3> in <module>
#       4 print("안녕하세요"[3])
#       5 print("안녕하세요"[4])
# ----> 6 print("안녕하세요"[5])
#       7 # 파이썬은 인덱싱을 할 때 0부터 시작한다 0을 1로 취급
#       8
#
# IndexError: string index out of range

# %%
# 인덱스 번호를 음수로 사용
print("안녕하세요"[-0])
print("안녕하세요"[-1])
print("안녕하세요"[-2])
print("안녕하세요"[-3])
print("안녕하세요"[-4])
print("안녕하세요"[-5])
# Out:
# 안
# 요
# 세
# 하
# 녕
# 안

# %%
# 인덱싱은 끝 번호를 포함하지 않음 [1:4] -> [1:3]
# 문자열 슬라이싱
print("안녕하세요"[1:4]) #1~3
print("안녕하세요"[0:5]) 
print("안녕하세요"[0:2])
print("안녕하세요"[2:4])
# Out:
# 녕하세
# 안녕하세요
# 안녕
# 하세

# %%
print("안녕하세요"[1:])
print("안녕하세요"[:3])
print("안녕하세요"[:2+1])
# Out:
# 녕하세요
# 안녕하
# 안녕하

# %%
print("안녕하세요"[5])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-84-69e86a823cc4> in <module>
# ----> 1 print("안녕하세요"[5])
#
# IndexError: string index out of range

# %%
print("안녕하세요"[10])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-86-31d7842c8b75> in <module>
# ----> 1 print("안녕하세요"[10])
#
# IndexError: string index out of range

# %%
# 문자열 길이 구하는 함수
len("안녕하세요")
# Out:
# 5

# %%
print("안녕하세요"[:3])
# Out:
# 안녕하

# %%
# 숫자
# 정수형 = integer = int
print(273)
print(type(273))
# Out:
# 273
# <class 'int'>

# %%
# 실수형 = float
print(52.278)
print(type(52.278))
# Out:
# 52.278
# <class 'float'>

# %%
# R에서의 목 %/% 나머지 %%
print(3/2) # 나누기
print(3//2) # 몫
print(3%2) # 나머지
# Out:
# 1.5
# 1
# 1

# %%
# 제곱 = R 에서는 ** ^
# 파이썬에서는 **
2**2
2**3
2**4
# Out:
# 16

# %%
2+(2*2)
2+2-2*2/2*2
2-2+2/2*2+2
2+2-(((2*2)/2)*2)
5+3*2
(5+3)*2
# Out:
# 16

# %%
# TypeError
number = 4
string = "랑해"
number + string
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-109-2d43afc7aa79> in <module>
#       2 number = 4
#       3 string = "랑해"
# ----> 4 number + string
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
number = "4"
string = "랑해"
number + string
# Out:
# '4랑해'

# %%
# 문자열 연산자의 우선순위
print("안녕"+"하세요"*3)
# Out:
# 안녕하세요하세요하세요

# %%
print(("안녕"+"하세요")*3)
# Out:
# 안녕하세요안녕하세요안녕하세요

# %%
print("안녕"+("하세요"*3))
# Out:
# 안녕하세요하세요하세요

# %%
print (2-2+2*2/2+2)
15/4
# Out:
# 4.0
# 3.75

# %%
# 확인 문제 3번
print("# 기본적인 연산")
# Out:
# # 기본적인 연산
