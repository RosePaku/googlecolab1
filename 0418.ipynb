# %%
# 튜플 = 리스트와 거의 유사
tuple_a = (1,2,3)

# 튜플의 원소에 접근하여 출력
print(tuple_a[0])  # 출력 결과: 1
print(tuple_a[1])  # 출력 결과: 2
print(tuple_a[2])  # 출력 결과: 3

tuple_a[0] = 10  # 튜플은 원소의 값 변경이 불가능하므로 에러 발생

# 튜플은 immutable(불변)한 자료형으로, 한 번 생성된 후에는 원소의 값을 변경할 수 없음
# 따라서 tuple_a[0] = 10과 같이 원소의 값을 변경하려고 하면 에러가 발생함
# Out:
# 1
# 2
# 3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-131-0cdae0620c18> in <cell line: 8>()
#       6 print(tuple_a[2])
#       7
# ----> 8 tuple_a[0] = 10
#
# TypeError: 'tuple' object does not support item assignment

# %%
# 소괄호가 없는 튜플
[a,b] = [1,2]
(c,d) = (3,4)
print(a,b,c,d)
# Out:
# 1 2 3 4

# %%
e = 1,2,3,4
print(e)
print(type(e))
# Out:
# (1, 2, 3, 4)
# <class 'tuple'>

# %%
f,g,h = 5,6,7
print(f,g,h)
# Out:
# 5 6 7

# %%
a,b = 1,2
print("교환하기 전의 a,b의 값 : {},{}".format(a,b))
a,b = b,a
print("교환하기 전의 a,b의 값 : {},{}".format(a,b))
# Out:
# 교환하기 전의 a,b의 값 : 1,2
# 교환하기 전의 a,b의 값 : 2,1

# %%
# 튜플과 함수
def test():
  return (1,2)
a,b = test() # a, b = 1,2
print(a,b)
# Out:
# 1 2

# %%
# 튜플을 리턴하는 함수
for i, j in enumerate([1,2,3,4]):
  print("인덱스: {}, 값: {}".format(i,j))
# Out:
# 인덱스: 0, 값: 1
# 인덱스: 1, 값: 2
# 인덱스: 2, 값: 3
# 인덱스: 3, 값: 4

# %%
# 딕셔너리 # 동일한 결과값
for i, j in {0:1,1:2,2:3,3:4}.items():
  print("인덱스: {}, 값: {}".format(i,j))
# Out:
# 인덱스: 0, 값: 1
# 인덱스: 1, 값: 2
# 인덱스: 2, 값: 3
# 인덱스: 3, 값: 4

# %%
a,b= 63, 30
print(a//b)
print(a%b)
# Out:
# 2
# 3

# %%
c,d =divmod(a,b)
print(c,d)
# Out:
# 2 3

# %%
# 람다
def repeatten(fx):
    for i in range(10): # 10번 반복하는 for 루프
        fx() # 인자로 받은 함수 fx()를 호출

def printhi():
    print("Hi")

repeatten(printhi) # printhi 함수를 repeatten 함수에 인자로 전달하여 10번 "Hi"를 출력하도록 동작
# Out:
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi
# Hi

# %%
# map & filter (함수, 리스트)
def power(item):
    return item**2

def under_3(item):
    return item < 3

list_a = [1, 2, 3, 4, 5]

output_map = map(power, list_a) # map 함수를 사용하여 list_a의 각 요소에 power 함수를 적용하여 새로운 리스트를 생성
print(output_map)
print(list(output_map)) # map 함수를 사용하여 생성된 리스트를 출력

output_filter = filter(under_3, list_a) # filter 함수를 사용하여 list_a의 각 요소에 under_3 함수를 적용하여 조건을 만족하는 요소만으로 이루어진 새로운 리스트를 생성
print(output_filter)
print(list(output_filter)) # filter 함수를 사용하여 생성된 리스트를 출력
# Out:
# <map object at 0x7f8ee43aa610>
# [1, 4, 9, 16, 25]
# <filter object at 0x7f8ee43aa3a0>
# [1, 2]

# %%
# 람다로 변경
power = lambda x: x**2  # 람다 함수를 사용하여 x의 제곱을 반환하는 함수를 정의
under_3 = lambda x: x<3  # 람다 함수를 사용하여 x가 3보다 작은지를 확인하는 함수를 정의

list_a = [1, 2, 3, 4, 5]

output_map = map(power, list_a)  # map 함수를 사용하여 list_a의 각 요소에 power 함수를 적용하여 새로운 리스트를 생성
print(output_map)
print(list(output_map))  # map 함수를 사용하여 생성된 리스트를 출력

output_filter = filter(under_3, list_a)  # filter 함수를 사용하여 list_a의 각 요소에 under_3 함수를 적용하여 조건을 만족하는 요소만으로 이루어진 새로운 리스트를 생성
print(output_filter)
print(list(output_filter))  # filter 함수를 사용하여 생성된 리스트를 출력
# Out:
# <map object at 0x7f8ee434b490>
# [1, 4, 9, 16, 25]
# <filter object at 0x7f8ee434b220>
# [1, 2]

# %%
# 더 단축시키기
list_a = [1, 2, 3, 4, 5]

output_map = map(lambda x: x**2, list_a)  # map 함수를 사용하여 list_a의 각 요소에 람다 함수를 적용하여 새로운 리스트를 생성
print(output_map)
print(list(output_map))  # map 함수를 사용하여 생성된 리스트를 출력

output_filter = filter(lambda x: x<3, list_a)  # filter 함수를 사용하여 list_a의 각 요소에 람다 함수를 적용하여 조건을 만족하는 요소만으로 이루어진 새로운 리스트를 생성
print(output_filter)
print(list(output_filter))  # filter 함수를 사용하여 생성된 리스트를 출력
# Out:
# <map object at 0x7f8ee434b880>
# [1, 4, 9, 16, 25]
# <filter object at 0x7f8ee434b190>
# [1, 2]

# %%
# 파일 처리
# 파일 열고 닫기
file = open("basic.txt","w")
# 텍스트 쓰기
file.write("안녕 파이썬 재밌니")
# 파일 닫기
file.close()

# %%
# 키워드 with 로 변경
# 파일 열고 닫기
with open("basic.txt","w")as file:
  # 파일에 텍스트를 씁니다.
  file.write("0418 비내리는 날")

# %%
# 텍스트 읽기
with open("basic.txt","r")as file:
  con = file.read()
print(con)
# Out:
# 0418 비내리는 날

# %%
# 텍스트 한 줄씩 읽기
# csv 텍스트 파일 만들기

import random

hg = list("가나다라마바사아자차카타파하")

# info.txt 파일을 쓰기 모드로 열기
with open("info.txt", "w") as file:
  # 1000번 반복하여 텍스트 파일에 데이터 쓰기
  for i in range(1000):
    # 이름, 몸무게, 키를 랜덤하게 생성
    name = random.choice(hg) + random.choice(hg) + random.choice(hg)
    weight = random.randrange(40,150)
    height = random.randrange(130,210)
    
    # 텍스트 파일에 데이터 쓰기
    file.write("{}, {}, {}\n".format(name, weight, height))

# %%
# 데이터를 한 줄씩 읽기 - 변수 새로 만들기
with open("info.txt","r") as file:
  for line in file:
    (name, weight, height) = line.strip().split(", ") # line = 이름, 몸무게,키
    if (not name) or (not weight) or (not height):
      continue
    bmi = int(weight) / ((int(height)/100) ** 2)
    result = ""
    if 25 <= bmi:
      result = "과체중"
    elif 18.5 <= bmi:
      result = "정상체중"
    else:
      result = "저체중"
    
    print("\n".join(["이름:{}",
                "몸무게: {}",
                "키:{}",
                "bmi:{}",
                "결과:{}"]).format(name,weight,height,bmi,result))
    print()

# 파일 만들 때 공백을 안 넣어서 공백 제거가 의미가 없어졌던 부분임
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 결과:과체중
#
# 이름:마아아
# 몸무게: 79
# 키:199
# bmi:19.948991187091234
# 결과:정상체중
#
# 이름:다마자
# 몸무게: 52
# 키:194
# bmi:13.81655861409289
# 결과:저체중
#
# 이름:하타아
# 몸무게: 134
# 키:197
# bmi:34.528073385039555
# 결과:과체중
#
# 이름:마마다
# 몸무게: 42
# 키:142
# bmi:20.829200555445347
# 결과:정상체중
#
# 이름:다파파
# 몸무게: 98
# 키:142
# bmi:48.60146796270581
# 결과:과체중
#
# 이름:자차라
# 몸무게: 95
# 키:196
# bmi:24.729279466888798
# 결과:정상체중
#
# 이름:바하타
# 몸무게: 42
# 키:146
# bmi:19.703509101144682
# 결과:정상체중
#
# 이름:파타아
# 몸무게: 108
# 키:154
# bmi:45.53887670770788
# 결과:과체중
#
# 이름:나마가
# 몸무게: 110
# 키:200
# bmi:27.5
# 결과:과체중
#
# 이름:자다차
# 몸무게: 145
# 키:199
# bmi:36.615236988964924
# 결과:과체중
#
# 이름:사아아
# 몸무게: 117
# 키:190
# bmi:32.40997229916898
# 결과:과체중
#
# 이름:다차하
# 몸무게: 148
# 키:201
# bmi:36.63275661493528
# 결과:과체중
#
# 이름:사다다
# 몸무게: 74
# 키:208
# bmi:17.1042899408284
# 결과:저체중
#
# 이름:라아차
# 몸무게: 69
# 키:130
# bmi:40.8284023668639
# 결과:과체중
#
# 이름:가나나
# 몸무게: 81
# 키:198
# bmi:20.66115702479339
# 결과:정상체중
#
# 이름:나파마
# 몸무게: 65
# 키:201
# bmi:16.088710675478335
# 결과:저체중
#
# 이름:파차하
# 몸무게: 126
# 키:146
# bmi:59.11052730343405
# 결과:과체중
#
# 이름:차파자
# 몸무게: 52
# 키:168
# bmi:18.42403628117914
# 결과:저체중
#
# 이름:아다카
# 몸무게: 52
# 키:207
# bmi:12.13563910476324
# 결과:저체중
#
# 이름:가차바
# 몸무게: 84
# 키:154
# bmi:35.41912632821724
# 결과:과체중
#
# 이름:가마파
# 몸무게: 98
# 키:144
# bmi:47.260802469135804
# 결과:과체중
#
# 이름:아라하
# 몸무게: 71
# 키:147
# bmi:32.85668008700079
# 결과:과체중
#
# 이름:나다사
# 몸무게: 68
# 키:136
# bmi:36.764705882352935
# 결과:과체중
#
# 이름:하가차
# 몸무게: 56
# 키:142
# bmi:27.772267407260465
# 결과:과체중
#
# 이름:바차자
# 몸무게: 93
# 키:132
# bmi:53.374655647382916
# 결과:과체중
#
# 이름:나하가
# 몸무게: 76
# 키:137
# bmi:40.49230113485002
# 결과:과체중
#
# 이름:라마타
# 몸무게: 113
# 키:205
# bmi:26.888756692444975
# 결과:과체중
#
# 이름:사자파
# 몸무게: 125
# 키:152
# bmi:54.103185595567865
# 결과:과체중
#
# 이름:마바라
# 몸무게: 122
# 키:157
# bmi:49.494908515558436
# 결과:과체중
#
# 이름:사다가
# 몸무게: 147
# 키:189
# bmi:41.1522633744856
# 결과:과체중
#
# 이름:다하자
# 몸무게: 105
# 키:142
# bmi:52.07300138861337
# 결과:과체중
#
# 이름:바마카
# 몸무게: 41
# 키:140
# bmi:20.91836734693878
# 결과:정상체중
#
# 이름:카바사
# 몸무게: 137
# 키:175
# bmi:44.734693877551024
# 결과:과체중
#
# 이름:다카자
# 몸무게: 110
# 키:202
# bmi:26.958141358690323
# 결과:과체중
#
# 이름:라파나
# 몸무게: 115
# 키:185
# bmi:33.60116873630387
# 결과:과체중
#
# 이름:타자차
# 몸무게: 55
# 키:207
# bmi:12.835772130038043
# 결과:저체중
#
# 이름:나파하
# 몸무게: 77
# 키:209
# bmi:17.62780156131957
# 결과:저체중
#
# 이름:차마마
# 몸무게: 71
# 키:138
# bmi:37.28208359588322
# 결과:과체중
#
# 이름:자파사
# 몸무게: 70
# 키:172
# bmi:23.661438615467823
# 결과:정상체중
#
# 이름:사차카
# 몸무게: 114
# 키:181
# bmi:34.79747260462135
# 결과:과체중
#
# 이름:아하자
# 몸무게: 89
# 키:130
# bmi:52.66272189349112
# 결과:과체중
#
# 이름:라가자
# 몸무게: 61
# 키:142
# bmi:30.251934140051578
# 결과:과체중
#
# 이름:카바다
# 몸무게: 40
# 키:192
# bmi:10.850694444444445
# 결과:저체중
#
# 이름:사아사
# 몸무게: 73
# 키:140
# bmi:37.24489795918368
# 결과:과체중
#
# 이름:카아파
# 몸무게: 85
# 키:180
# bmi:26.234567901234566
# 결과:과체중
#
# 이름:다파자
# 몸무게: 57
# 키:136
# bmi:30.8174740484429
# 결과:과체중
#
# 이름:마아나
# 몸무게: 143
# 키:184
# bmi:42.23771266540643
# 결과:과체중
#
# 이름:가하차
# 몸무게: 70
# 키:135
# bmi:38.40877914951989
# 결과:과체중
#
# 이름:사카마
# 몸무게: 78
# 키:198
# bmi:19.89592898683808
# 결과:정상체중
#
# 이름:바파카
# 몸무게: 56
# 키:175
# bmi:18.285714285714285
# 결과:저체중
#
# 이름:카바다
# 몸무게: 142
# 키:178
# bmi:44.81757353869461
# 결과:과체중
#
# 이름:아아타
# 몸무게: 127
# 키:152
# bmi:54.96883656509695
# 결과:과체중
#
# 이름:바라차
# 몸무게: 101
# 키:159
# bmi:39.95095130730588
# 결과:과체중
#
# 이름:자자아
# 몸무게: 142
# 키:208
# bmi:32.821745562130175
# 결과:과체중
#
# 이름:마다파
# 몸무게: 137
# 키:190
# bmi:37.95013850415513
# 결과:과체중
#
# 이름:가라바
# 몸무게: 62
# 키:141
# bmi:31.18555404657714
# 결과:과체중
#
# 이름:라마자
# 몸무게: 133
# 키:199
# bmi:33.585010479533345
# 결과:과체중
#
# 이름:타사라
# 몸무게: 62
# 키:135
# bmi:34.01920438957475
# 결과:과체중
#
# 이름:차라다
# 몸무게: 95
# 키:207
# bmi:22.170879133702073
# 결과:정상체중
#
# 이름:타타타
# 몸무게: 113
# 키:159
# bmi:44.697598987381824
# 결과:과체중
#
# 이름:라다카
# 몸무게: 123
# 키:171
# bmi:42.06422488970966
# 결과:과체중
#
# 이름:사자하
# 몸무게: 148
# 키:185
# bmi:43.24324324324324
# 결과:과체중
#
# 이름:사라카
# 몸무게: 50
# 키:186
# bmi:14.452537865649207
# 결과:저체중
#
# 이름:파나아
# 몸무게: 65
# 키:136
# bmi:35.14273356401383
# 결과:과체중
#
# 이름:마파가
# 몸무게: 120
# 키:192
# bmi:32.552083333333336
# 결과:과체중
#
# 이름:다차라
# 몸무게: 60
# 키:187
# bmi:17.158054276645025
# 결과:저체중
#
# 이름:차파파
# 몸무게: 112
# 키:164
# bmi:41.64187983343249
# 결과:과체중
#
# 이름:사라하
# 몸무게: 141
# 키:209
# bmi:32.279480781117655
# 결과:과체중
#
# 이름:하나다
# 몸무게: 129
# 키:152
# bmi:55.834487534626035
# 결과:과체중
#
# 이름:마카타
# 몸무게: 106
# 키:162
# bmi:40.39018442310623
# 결과:과체중
#
# 이름:다차차
# 몸무게: 132
# 키:133
# bmi:74.62264684267058
# 결과:과체중
#
# 이름:나바사
# 몸무게: 83
# 키:168
# bmi:29.40759637188209
# 결과:과체중
#
# 이름:파타자
# 몸무게: 80
# 키:204
# bmi:19.223375624759708
# 결과:정상체중
#
# 이름:나가마
# 몸무게: 131
# 키:185
# bmi:38.276113951789625
# 결과:과체중
#
# 이름:차카하
# 몸무게: 64
# 키:159
# bmi:25.315454293738377
# 결과:과체중
#
# 이름:차차파
# 몸무게: 68
# 키:177
# bmi:21.705129432793896
# 결과:정상체중
#
# 이름:다아나
# 몸무게: 145
# 키:147
# bmi:67.10167060021288
# 결과:과체중
#
# 이름:사가바
# 몸무게: 64
# 키:201
# bmi:15.841192049701744
# 결과:저체중
#
# 이름:라아차
# 몸무게: 114
# 키:198
# bmi:29.07866544230181
# 결과:과체중
#
# 이름:하나타
# 몸무게: 145
# 키:146
# bmi:68.02401951585664
# 결과:과체중
#
# 이름:카가자
# 몸무게: 99
# 키:146
# bmi:46.443985738412465
# 결과:과체중
#
# 이름:라파카
# 몸무게: 88
# 키:190
# bmi:24.37673130193906
# 결과:정상체중
#
# 이름:파바파
# 몸무게: 58
# 키:156
# bmi:23.83300460223537
# 결과:정상체중
#
# 이름:아라가
# 몸무게: 111
# 키:172
# bmi:37.52028123309898
# 결과:과체중
#
# 이름:카사타
# 몸무게: 121
# 키:156
# bmi:49.72057856673241
# 결과:과체중
#
# 이름:가아파
# 몸무게: 112
# 키:184
# bmi:33.0812854442344
# 결과:과체중
#
# 이름:타마자
# 몸무게: 91
# 키:163
# bmi:34.25044224472129
# 결과:과체중
#
# 이름:라아나
# 몸무게: 129
# 키:157
# bmi:52.33478031563146
# 결과:과체중
#
# 이름:가자타
# 몸무게: 76
# 키:174
# bmi:25.102391333069097
# 결과:과체중
#
# 이름:가카바
# 몸무게: 75
# 키:186
# bmi:21.678806798473808
# 결과:정상체중
#
# 이름:나파마
# 몸무게: 145
# 키:133
# bmi:81.97184691050936
# 결과:과체중
#
# 이름:사마카
# 몸무게: 112
# 키:130
# bmi:66.27218934911242
# 결과:과체중
#
# 이름:나사자
# 몸무게: 130
# 키:206
# bmi:30.634367046847018
# 결과:과체중
#
# 이름:하라가
# 몸무게: 100
# 키:181
# bmi:30.52409877598364
# 결과:과체중
#
# 이름:다차바
# 몸무게: 102
# 키:177
# bmi:32.557694149190844
# 결과:과체중
#
# 이름:사바하
# 몸무게: 129
# 키:162
# bmi:49.1540923639689
# 결과:과체중
#
# 이름:카차다
# 몸무게: 98
# 키:163
# bmi:36.88509164816139
# 결과:과체중
#
# 이름:가자나
# 몸무게: 77
# 키:158
# bmi:30.844415958980928
# 결과:과체중
#
# 이름:가가바
# 몸무게: 122
# 키:147
# bmi:56.457957332592905
# 결과:과체중
#
# 이름:바다파
# 몸무게: 142
# 키:181
# bmi:43.344220261896766
# 결과:과체중
#
# 이름:아하카
# 몸무게: 49
# 키:208
# bmi:11.325813609467454
# 결과:저체중
#
# 이름:다하타
# 몸무게: 120
# 키:132
# bmi:68.87052341597796
# 결과:과체중
#
# 이름:아가가
# 몸무게: 113
# 키:167
# bmi:40.517766861486606
# 결과:과체중
#
# 이름:라바카
# 몸무게: 96
# 키:181
# bmi:29.303134824944294
# 결과:과체중
#
# 이름:가다사
# 몸무게: 88
# 키:130
# bmi:52.07100591715976
# 결과:과체중
#
# 이름:나타차
# 몸무게: 57
# 키:177
# bmi:18.194005553959588
# 결과:저체중
#
# 이름:아바하
# 몸무게: 64
# 키:207
# bmi:14.936171205862449
# 결과:저체중
#
# 이름:가마파
# 몸무게: 149
# 키:135
# bmi:81.75582990397804
# 결과:과체중
#
# 이름:마나아
# 몸무게: 84
# 키:189
# bmi:23.515579071134628
# 결과:정상체중
#
# 이름:라하마
# 몸무게: 42
# 키:130
# bmi:24.852071005917157
# 결과:정상체중
#
# 이름:라바다
# 몸무게: 114
# 키:198
# bmi:29.07866544230181
# 결과:과체중
#
# 이름:바다나
# 몸무게: 110
# 키:172
# bmi:37.182260681449435
# 결과:과체중
#
# 이름:가자마
# 몸무게: 69
# 키:147
# bmi:31.93113980285992
# 결과:과체중
#
# 이름:아다차
# 몸무게: 96
# 키:200
# bmi:24.0
# 결과:정상체중
#
# 이름:가하아
# 몸무게: 78
# 키:131
# bmi:45.45189674261406
# 결과:과체중
#
# 이름:자아차
# 몸무게: 54
# 키:137
# bmi:28.770845543182904
# 결과:과체중
#
# 이름:카나다
# 몸무게: 82
# 키:168
# bmi:29.053287981859416
# 결과:과체중
#
# 이름:자아차
# 몸무게: 145
# 키:135
# bmi:79.56104252400547
# 결과:과체중
#
# 이름:차아마
# 몸무게: 104
# 키:139
# bmi:53.82744164380726
# 결과:과체중
#
# 이름:하파가
# 몸무게: 141
# 키:147
# bmi:65.25059003193114
# 결과:과체중
#
# 이름:사하하
# 몸무게: 61
# 키:159
# bmi:24.128792373719392
# 결과:정상체중
#
# 이름:가카아
# 몸무게: 58
# 키:130
# bmi:34.319526627218934
# 결과:과체중
#
# 이름:다라나
# 몸무게: 83
# 키:139
# bmi:42.958439004192336
# 결과:과체중
#
# 이름:하자다
# 몸무게: 139
# 키:132
# bmi:79.77502295684113
# 결과:과체중
#
# 이름:타자하
# 몸무게: 109
# 키:146
# bmi:51.1352974291612
# 결과:과체중
#
# 이름:사가자
# 몸무게: 71
# 키:199
# bmi:17.928840180803515
# 결과:저체중
#
# 이름:바나하
# 몸무게: 111
# 키:186
# bmi:32.08463406174124
# 결과:과체중
#
# 이름:파라카
# 몸무게: 76
# 키:157
# bmi:30.832893829364274
# 결과:과체중
#
# 이름:가타사
# 몸무게: 58
# 키:141
# bmi:29.17358281776571
# 결과:과체중
#
# 이름:자자카
# 몸무게: 90
# 키:205
# bmi:21.415823914336706
# 결과:정상체중
#
# 이름:사차라
# 몸무게: 70
# 키:159
# bmi:27.688778133776353
# 결과:과체중
#
# 이름:자라차
# 몸무게: 145
# 키:149
# bmi:65.31237331651728
# 결과:과체중
#
# 이름:사라파
# 몸무게: 131
# 키:178
# bmi:41.34578967302108
# 결과:과체중
#
# 이름:바자가
# 몸무게: 118
# 키:132
# bmi:67.72268135904498
# 결과:과체중
#
# 이름:자가파
# 몸무게: 109
# 키:199
# bmi:27.524557460670184
# 결과:과체중
#
# 이름:카바나
# 몸무게: 109
# 키:149
# bmi:49.09688752758885
# 결과:과체중
#
# 이름:카사사
# 몸무게: 91
# 키:142
# bmi:45.12993453679825
# 결과:과체중
#
# 이름:아바차
# 몸무게: 145
# 키:164
# bmi:53.91136228435456
# 결과:과체중
#
# 이름:카사하
# 몸무게: 99
# 키:194
# bmi:26.304601976830696
# 결과:과체중
#
# 이름:가카하
# 몸무게: 56
# 키:169
# bmi:19.607156612163443
# 결과:정상체중
#
# 이름:사가차
# 몸무게: 69
# 키:182
# bmi:20.830817534114235
# 결과:정상체중
#
# 이름:나가아
# 몸무게: 101
# 키:182
# bmi:30.491486535442576
# 결과:과체중
#
# 이름:나가파
# 몸무게: 119
# 키:208
# bmi:27.505547337278102
# 결과:과체중
#
# 이름:하라사
# 몸무게: 89
# 키:140
# bmi:45.40816326530613
# 결과:과체중
#
# 이름:차아가
# 몸무게: 143
# 키:176
# bmi:46.16477272727273
# 결과:과체중
#
# 이름:차다카
# 몸무게: 78
# 키:144
# bmi:37.61574074074074
# 결과:과체중
#
# 이름:파다카
# 몸무게: 113
# 키:200
# bmi:28.25
# 결과:과체중
#
# 이름:아카나
# 몸무게: 80
# 키:182
# bmi:24.151672503320853
# 결과:정상체중
#
# 이름:파바파
# 몸무게: 140
# 키:191
# bmi:38.376141004906664
# 결과:과체중
#
# 이름:파사파
# 몸무게: 113
# 키:136
# bmi:61.09429065743944
# 결과:과체중
#
# 이름:차사자
# 몸무게: 65
# 키:168
# bmi:23.030045351473927
# 결과:정상체중
#
# 이름:사마하
# 몸무게: 94
# 키:174
# bmi:31.04769454353283
# 결과:과체중
#
# 이름:다자파
# 몸무게: 128
# 키:164
# bmi:47.59071980963713
# 결과:과체중
#
# 이름:바라아
# 몸무게: 91
# 키:191
# bmi:24.94449165318933
# 결과:정상체중
#
# 이름:파가다
# 몸무게: 65
# 키:164
# bmi:24.167162403331353
# 결과:정상체중
#
# 이름:마차하
# 몸무게: 45
# 키:199
# bmi:11.363349410368425
# 결과:저체중
#
# 이름:차파다
# 몸무게: 100
# 키:154
# bmi:42.165626581211
# 결과:과체중
#
# 이름:하자카
# 몸무게: 101
# 키:200
# bmi:25.25
# 결과:과체중
#
# 이름:하다바
# 몸무게: 111
# 키:203
# bmi:26.935863524958148
# 결과:과체중
#
# 이름:카나마
# 몸무게: 69
# 키:189
# bmi:19.31636852271773
# 결과:정상체중
#
# 이름:자라파
# 몸무게: 48
# 키:133
# bmi:27.135507942789303
# 결과:과체중
#
# 이름:나마다
# 몸무게: 43
# 키:161
# bmi:16.58886617028664
# 결과:저체중
#
# 이름:라라사
# 몸무게: 131
# 키:162
# bmi:49.91617131534826
# 결과:과체중
#
# 이름:하파하
# 몸무게: 79
# 키:195
# bmi:20.77580539119001
# 결과:정상체중
#
# 이름:다파하
# 몸무게: 113
# 키:190
# bmi:31.301939058171747
# 결과:과체중
#
# 이름:하파다
# 몸무게: 40
# 키:168
# bmi:14.172335600907031
# 결과:저체중
#
# 이름:파나라
# 몸무게: 60
# 키:144
# bmi:28.935185185185187
# 결과:과체중
#
# 이름:하파카
# 몸무게: 109
# 키:192
# bmi:29.56814236111111
# 결과:과체중
#
# 이름:자아차
# 몸무게: 105
# 키:144
# bmi:50.636574074074076
# 결과:과체중
#
# 이름:카아타
# 몸무게: 60
# 키:131
# bmi:34.96299749431851
# 결과:과체중
#
# 이름:바자자
# 몸무게: 126
# 키:162
# bmi:48.01097393689985
# 결과:과체중
#
# 이름:가아타
# 몸무게: 88
# 키:197
# bmi:22.675152670772242
# 결과:정상체중
#
# 이름:아다자
# 몸무게: 49
# 키:134
# bmi:27.288928491869008
# 결과:과체중
#
# 이름:타하하
# 몸무게: 53
# 키:183
# bmi:15.826092149661081
# 결과:저체중
#
# 이름:아나가
# 몸무게: 93
# 키:170
# bmi:32.17993079584775
# 결과:과체중
#
# 이름:아바자
# 몸무게: 92
# 키:139
# bmi:47.61658299259874
# 결과:과체중
#
# 이름:라가자
# 몸무게: 74
# 키:136
# bmi:40.008650519031136
# 결과:과체중
#
# 이름:나카나
# 몸무게: 78
# 키:166
# bmi:28.305995064595734
# 결과:과체중
#
# 이름:바차카
# 몸무게: 70
# 키:199
# bmi:17.67632130501755
# 결과:저체중
#
# 이름:자사차
# 몸무게: 121
# 키:160
# bmi:47.26562499999999
# 결과:과체중
#
# 이름:가아파
# 몸무게: 53
# 키:206
# bmi:12.489395796022245
# 결과:저체중
#
# 이름:다자차
# 몸무게: 85
# 키:181
# bmi:25.94548395958609
# 결과:과체중
#
# 이름:차라하
# 몸무게: 74
# 키:143
# bmi:36.18758863514109
# 결과:과체중
#
# 이름:바하다
# 몸무게: 89
# 키:194
# bmi:23.647571474120525
# 결과:정상체중
#
# 이름:다아차
# 몸무게: 137
# 키:196
# bmi:35.662224073302795
# 결과:과체중
#
# 이름:사가나
# 몸무게: 75
# 키:159
# bmi:29.666548000474663
# 결과:과체중
#
# 이름:차가사
# 몸무게: 42
# 키:175
# bmi:13.714285714285714
# 결과:저체중
#
# 이름:파하타
# 몸무게: 111
# 키:154
# bmi:46.80384550514421
# 결과:과체중
#
# 이름:타자사
# 몸무게: 60
# 키:193
# bmi:16.107814974898655
# 결과:저체중
#
# 이름:사다가
# 몸무게: 85
# 키:143
# bmi:41.566824783608006
# 결과:과체중
#
# 이름:차사다
# 몸무게: 53
# 키:164
# bmi:19.705532421177875
# 결과:정상체중
#
# 이름:바가사
# 몸무게: 129
# 키:179
# bmi:40.26091570175713
# 결과:과체중
#
# 이름:자카자
# 몸무게: 138
# 키:192
# bmi:37.434895833333336
# 결과:과체중
#
# 이름:사사차
# 몸무게: 78
# 키:170
# bmi:26.989619377162633
# 결과:과체중
#
# 이름:사파아
# 몸무게: 49
# 키:144
# bmi:23.630401234567902
# 결과:정상체중
#
# 이름:차바다
# 몸무게: 71
# 키:153
# bmi:30.33021487462087
# 결과:과체중
#
# 이름:카타다
# 몸무게: 49
# 키:135
# bmi:26.88614540466392
# 결과:과체중
#
# 이름:파바바
# 몸무게: 141
# 키:172
# bmi:47.66089778258519
# 결과:과체중
#
# 이름:타마카
# 몸무게: 95
# 키:192
# bmi:25.770399305555557
# 결과:과체중
#
# 이름:카카자
# 몸무게: 138
# 키:209
# bmi:31.59268331768962
# 결과:과체중
#
# 이름:다사타
# 몸무게: 49
# 키:156
# bmi:20.134779750164363
# 결과:정상체중
#
# 이름:타나자
# 몸무게: 43
# 키:136
# bmi:23.24826989619377
# 결과:정상체중
#
# 이름:가바라
# 몸무게: 119
# 키:173
# bmi:39.76076714891911
# 결과:과체중
#
# 이름:나자차
# 몸무게: 72
# 키:165
# bmi:26.44628099173554
# 결과:과체중
#
# 이름:파타마
# 몸무게: 51
# 키:198
# bmi:13.008876645240282
# 결과:저체중
#
# 이름:마자라
# 몸무게: 63
# 키:202
# bmi:15.439662778159004
# 결과:저체중
#
# 이름:가나마
# 몸무게: 126
# 키:130
# bmi:74.55621301775147
# 결과:과체중
#
# 이름:하나나
# 몸무게: 89
# 키:185
# bmi:26.004382761139514
# 결과:과체중
#
# 이름:하가파
# 몸무게: 89
# 키:204
# bmi:21.386005382545175
# 결과:정상체중
#
# 이름:카카가
# 몸무게: 66
# 키:130
# bmi:39.05325443786982
# 결과:과체중
#
# 이름:자마마
# 몸무게: 41
# 키:173
# bmi:13.69908784122423
# 결과:저체중
#
# 이름:자다마
# 몸무게: 131
# 키:198
# bmi:33.4149576573819
# 결과:과체중
#
# 이름:사차마
# 몸무게: 98
# 키:148
# bmi:44.74068663257852
# 결과:과체중
#
# 이름:아차바
# 몸무게: 68
# 키:135
# bmi:37.311385459533604
# 결과:과체중
#
# 이름:라라라
# 몸무게: 134
# 키:158
# bmi:53.67729530523954
# 결과:과체중
#
# 이름:파아마
# 몸무게: 103
# 키:198
# bmi:26.272829303132333
# 결과:과체중
#
# 이름:나다하
# 몸무게: 59
# 키:134
# bmi:32.85809757184227
# 결과:과체중
#
# 이름:가라타
# 몸무게: 130
# 키:164
# bmi:48.33432480666271
# 결과:과체중
#
# 이름:자나카
# 몸무게: 87
# 키:154
# bmi:36.68409512565357
# 결과:과체중
#
# 이름:라자아
# 몸무게: 120
# 키:141
# bmi:60.359136864342844
# 결과:과체중
#
# 이름:아사자
# 몸무게: 71
# 키:142
# bmi:35.2112676056338
# 결과:과체중
#
# 이름:카타사
# 몸무게: 79
# 키:141
# bmi:39.73643176902571
# 결과:과체중
#
# 이름:아라마
# 몸무게: 51
# 키:153
# bmi:21.78649237472767
# 결과:정상체중
#
# 이름:나차마
# 몸무게: 48
# 키:204
# bmi:11.534025374855824
# 결과:저체중
#
# 이름:아하자
# 몸무게: 123
# 키:152
# bmi:53.23753462603878
# 결과:과체중
#
# 이름:사자라
# 몸무게: 75
# 키:131
# bmi:43.70374686789814
# 결과:과체중
#
# 이름:바아가
# 몸무게: 87
# 키:172
# bmi:29.40778799351001
# 결과:과체중
#
# 이름:바다카
# 몸무게: 74
# 키:135
# bmi:40.60356652949245
# 결과:과체중
#
# 이름:차하하
# 몸무게: 101
# 키:192
# bmi:27.39800347222222
# 결과:과체중
#
# 이름:사바가
# 몸무게: 137
# 키:174
# bmi:45.250363324085086
# 결과:과체중
#
# 이름:사사사
# 몸무게: 45
# 키:179
# bmi:14.044505477357136
# 결과:저체중
#
# 이름:마타마
# 몸무게: 98
# 키:172
# bmi:33.12601406165495
# 결과:과체중
#
# 이름:라타바
# 몸무게: 91
# 키:169
# bmi:31.861629494765594
# 결과:과체중
#
# 이름:카다다
# 몸무게: 104
# 키:208
# bmi:24.038461538461537
# 결과:정상체중
#
# 이름:자하자
# 몸무게: 144
# 키:147
# bmi:66.63890045814244
# 결과:과체중
#
# 이름:아사나
# 몸무게: 91
# 키:143
# bmi:44.50095359186269
# 결과:과체중
#
# 이름:타아파
# 몸무게: 123
# 키:176
# bmi:39.7081611570248
# 결과:과체중
#
# 이름:차나카
# 몸무게: 43
# 키:209
# bmi:9.844096975801838
# 결과:저체중
#
# 이름:자나다
# 몸무게: 44
# 키:193
# bmi:11.812397648259013
# 결과:저체중
#
# 이름:마카하
# 몸무게: 80
# 키:134
# bmi:44.553352639786134
# 결과:과체중
#
# 이름:하라라
# 몸무게: 116
# 키:177
# bmi:37.02639726770723
# 결과:과체중
#
# 이름:자마라
# 몸무게: 147
# 키:141
# bmi:73.93994265881999
# 결과:과체중
#
# 이름:파나하
# 몸무게: 73
# 키:133
# bmi:41.268584996325394
# 결과:과체중
#
# 이름:카다아
# 몸무게: 111
# 키:158
# bmi:44.46402820060887
# 결과:과체중
#
# 이름:타차아
# 몸무게: 103
# 키:206
# bmi:24.271844660194176
# 결과:정상체중
#
# 이름:하다자
# 몸무게: 142
# 키:165
# bmi:52.15794306703398
# 결과:과체중
#
# 이름:차하카
# 몸무게: 85
# 키:171
# bmi:29.06877329776684
# 결과:과체중
#
# 이름:라바아
# 몸무게: 71
# 키:190
# bmi:19.667590027700832
# 결과:정상체중
#
# 이름:사라카
# 몸무게: 123
# 키:200
# bmi:30.75
# 결과:과체중
#
# 이름:바바사
# 몸무게: 45
# 키:200
# bmi:11.25
# 결과:저체중
#
# 이름:자아라
# 몸무게: 69
# 키:198
# bmi:17.600244872972148
# 결과:저체중
#
# 이름:타차자
# 몸무게: 51
# 키:164
# bmi:18.961927424152293
# 결과:정상체중
#
# 이름:파다카
# 몸무게: 50
# 키:196
# bmi:13.015410245730946
# 결과:저체중
#
# 이름:가나가
# 몸무게: 132
# 키:136
# bmi:71.3667820069204
# 결과:과체중
#
# 이름:아자바
# 몸무게: 114
# 키:173
# bmi:38.090146680477126
# 결과:과체중
#
# 이름:마카바
# 몸무게: 123
# 키:145
# bmi:58.501783590963136
# 결과:과체중
#
# 이름:바라사
# 몸무게: 79
# 키:147
# bmi:36.55884122356426
# 결과:과체중
#
# 이름:나파가
# 몸무게: 138
# 키:180
# bmi:42.59259259259259
# 결과:과체중
#
# 이름:라카자
# 몸무게: 90
# 키:160
# bmi:35.15624999999999
# 결과:과체중
#
# 이름:바타바
# 몸무게: 141
# 키:200
# bmi:35.25
# 결과:과체중
#
# 이름:파하카
# 몸무게: 113
# 키:131
# bmi:65.84697861429986
# 결과:과체중
#
# 이름:라아다
# 몸무게: 90
# 키:144
# bmi:43.40277777777778
# 결과:과체중
#
# 이름:나다사
# 몸무게: 72
# 키:198
# bmi:18.36547291092746
# 결과:저체중
#
# 이름:바아차
# 몸무게: 65
# 키:138
# bmi:34.13148498214662
# 결과:과체중
#
# 이름:카타다
# 몸무게: 66
# 키:189
# bmi:18.47652641303435
# 결과:저체중
#
# 이름:가타라
# 몸무게: 92
# 키:151
# bmi:40.349107495285295
# 결과:과체중
#
# 이름:차아가
# 몸무게: 63
# 키:162
# bmi:24.005486968449926
# 결과:정상체중
#
# 이름:바마자
# 몸무게: 122
# 키:165
# bmi:44.811753902663
# 결과:과체중
#
# 이름:다나하
# 몸무게: 79
# 키:193
# bmi:21.20862305028323
# 결과:정상체중
#
# 이름:사아다
# 몸무게: 114
# 키:155
# bmi:47.450572320499475
# 결과:과체중
#
# 이름:가자하
# 몸무게: 51
# 키:134
# bmi:28.40276230786366
# 결과:과체중
#
# 이름:라타사
# 몸무게: 125
# 키:182
# bmi:37.73698828643883
# 결과:과체중
#
# 이름:차바아
# 몸무게: 87
# 키:138
# bmi:45.68367989918085
# 결과:과체중
#
# 이름:자파바
# 몸무게: 94
# 키:155
# bmi:39.12591050988553
# 결과:과체중
#
# 이름:아자나
# 몸무게: 119
# 키:186
# bmi:34.39704012024511
# 결과:과체중
#
# 이름:다바카
# 몸무게: 149
# 키:196
# bmi:38.78592253227822
# 결과:과체중
#
# 이름:가라하
# 몸무게: 64
# 키:179
# bmi:19.97440779001904
# 결과:정상체중
#
# 이름:파가사
# 몸무게: 56
# 키:135
# bmi:30.72702331961591
# 결과:과체중
#
# 이름:가타카
# 몸무게: 132
# 키:132
# bmi:75.75757575757575
# 결과:과체중
#
# 이름:차타라
# 몸무게: 98
# 키:178
# bmi:30.930438076000502
# 결과:과체중
#
# 이름:자차라
# 몸무게: 123
# 키:172
# bmi:41.57652785289346
# 결과:과체중
#
# 이름:사사다
# 몸무게: 48
# 키:209
# bmi:10.988759414848563
# 결과:저체중
#
# 이름:사라하
# 몸무게: 80
# 키:149
# bmi:36.03441286428539
# 결과:과체중
#
# 이름:가아사
# 몸무게: 76
# 키:188
# bmi:21.50294250792214
# 결과:정상체중
#
# 이름:나가타
# 몸무게: 94
# 키:174
# bmi:31.04769454353283
# 결과:과체중
#
# 이름:라차하
# 몸무게: 46
# 키:130
# bmi:27.218934911242602
# 결과:과체중
#
# 이름:카하파
# 몸무게: 114
# 키:150
# bmi:50.666666666666664
# 결과:과체중
#
# 이름:나차하
# 몸무게: 60
# 키:173
# bmi:20.04744562130375
# 결과:정상체중
#
# 이름:마차카
# 몸무게: 142
# 키:192
# bmi:38.51996527777778
# 결과:과체중
#
# 이름:바파자
# 몸무게: 97
# 키:137
# bmi:51.680963290532254
# 결과:과체중
#
# 이름:파하카
# 몸무게: 116
# 키:155
# bmi:48.28303850156087
# 결과:과체중
#
# 이름:차나하
# 몸무게: 117
# 키:133
# bmi:66.14280061054892
# 결과:과체중
#
# 이름:바아바
# 몸무게: 59
# 키:165
# bmi:21.6712580348944
# 결과:정상체중
#
# 이름:라하라
# 몸무게: 122
# 키:203
# bmi:29.605183333737784
# 결과:과체중
#
# 이름:마가다
# 몸무게: 70
# 키:199
# bmi:17.67632130501755
# 결과:저체중
#
# 이름:자하나
# 몸무게: 118
# 키:191
# bmi:32.34560456127848
# 결과:과체중
#
# 이름:파하하
# 몸무게: 94
# 키:178
# bmi:29.667971215755585
# 결과:과체중
#
# 이름:차아나
# 몸무게: 134
# 키:200
# bmi:33.5
# 결과:과체중
#
# 이름:카카차
# 몸무게: 76
# 키:148
# bmi:34.69685902118335
# 결과:과체중
#
# 이름:마차바
# 몸무게: 66
# 키:177
# bmi:21.06674327300584
# 결과:정상체중
#
# 이름:차자마
# 몸무게: 136
# 키:133
# bmi:76.88393917123635
# 결과:과체중
#
# 이름:나자자
# 몸무게: 76
# 키:184
# bmi:22.448015122873343
# 결과:정상체중
#
# 이름:바바바
# 몸무게: 90
# 키:184
# bmi:26.583175803402646
# 결과:과체중
#
# 이름:가다마
# 몸무게: 99
# 키:161
# bmi:38.19297095019482
# 결과:과체중
#
# 이름:파하하
# 몸무게: 41
# 키:156
# bmi:16.847468770545692
# 결과:저체중
#
# 이름:마나다
# 몸무게: 44
# 키:177
# bmi:14.044495515337227
# 결과:저체중
#
# 이름:파타사
# 몸무게: 149
# 키:197
# bmi:38.39315622664846
# 결과:과체중
#
# 이름:바자하
# 몸무게: 41
# 키:194
# bmi:10.893825061111702
# 결과:저체중
#
# 이름:카가바
# 몸무게: 64
# 키:173
# bmi:21.383941996057334
# 결과:정상체중
#
# 이름:바자다
# 몸무게: 96
# 키:186
# bmi:27.748872702046476
# 결과:과체중
#
# 이름:아차차
# 몸무게: 123
# 키:139
# bmi:63.66130117488744
# 결과:과체중
#
# 이름:사파나
# 몸무게: 89
# 키:148
# bmi:40.6318480642805
# 결과:과체중
#
# 이름:마다바
# 몸무게: 68
# 키:143
# bmi:33.253459826886406
# 결과:과체중
#
# 이름:다아아
# 몸무게: 62
# 키:206
# bmi:14.610236591573193
# 결과:저체중
#
# 이름:나사라
# 몸무게: 137
# 키:180
# bmi:42.28395061728395
# 결과:과체중
#
# 이름:가라다
# 몸무게: 58
# 키:170
# bmi:20.06920415224914
# 결과:정상체중
#
# 이름:가나다
# 몸무게: 86
# 키:193
# bmi:23.087868130688072
# 결과:정상체중
#
# 이름:차차라
# 몸무게: 148
# 키:163
# bmi:55.70401595844782
# 결과:과체중
#
# 이름:아다타
# 몸무게: 138
# 키:195
# bmi:36.29191321499014
# 결과:과체중
#
# 이름:파파나
# 몸무게: 121
# 키:165
# bmi:44.44444444444445
# 결과:과체중
#
# 이름:라타차
# 몸무게: 83
# 키:194
# bmi:22.053353172494422
# 결과:정상체중
#
# 이름:나타카
# 몸무게: 115
# 키:175
# bmi:37.55102040816327
# 결과:과체중
#
# 이름:바아차
# 몸무게: 114
# 키:166
# bmi:41.370300479024536
# 결과:과체중
#
# 이름:사파자
# 몸무게: 115
# 키:178
# bmi:36.295922232041406
# 결과:과체중
#
# 이름:자파자
# 몸무게: 109
# 키:176
# bmi:35.18853305785124
# 결과:과체중
#
# 이름:다다자
# 몸무게: 77
# 키:190
# bmi:21.329639889196677
# 결과:정상체중
#
# 이름:나차하
# 몸무게: 68
# 키:188
# bmi:19.23947487550928
# 결과:정상체중
#
# 이름:사다차
# 몸무게: 45
# 키:172
# bmi:15.210924824229314
# 결과:저체중
#
# 이름:차마바
# 몸무게: 136
# 키:136
# bmi:73.52941176470587
# 결과:과체중
#
# 이름:가타하
# 몸무게: 67
# 키:130
# bmi:39.64497041420118
# 결과:과체중
#
# 이름:다차차
# 몸무게: 48
# 키:166
# bmi:17.419073885905068
# 결과:저체중
#
# 이름:차자바
# 몸무게: 61
# 키:152
# bmi:26.40235457063712
# 결과:과체중
#
# 이름:자바다
# 몸무게: 92
# 키:141
# bmi:46.27533826266285
# 결과:과체중
#
# 이름:바아마
# 몸무게: 104
# 키:170
# bmi:35.98615916955018
# 결과:과체중
#
# 이름:카타다
# 몸무게: 125
# 키:171
# bmi:42.7481960261277
# 결과:과체중
#
# 이름:바차다
# 몸무게: 108
# 키:188
# bmi:30.556813037573566
# 결과:과체중
#
# 이름:마아나
# 몸무게: 55
# 키:152
# bmi:23.80540166204986
# 결과:정상체중
#
# 이름:나파나
# 몸무게: 54
# 키:179
# bmi:16.853406572828565
# 결과:저체중
#
# 이름:나카라
# 몸무게: 63
# 키:157
# bmi:25.558846200657225
# 결과:과체중
#
# 이름:하가나
# 몸무게: 123
# 키:185
# bmi:35.938641344046744
# 결과:과체중
#
# 이름:카차바
# 몸무게: 131
# 키:133
# bmi:74.05732376052913
# 결과:과체중
#
# 이름:나다자
# 몸무게: 87
# 키:204
# bmi:20.90542099192618
# 결과:정상체중
#
# 이름:타바타
# 몸무게: 55
# 키:130
# bmi:32.54437869822485
# 결과:과체중
#
# 이름:파나타
# 몸무게: 62
# 키:168
# bmi:21.9671201814059
# 결과:정상체중
#
# 이름:마가다
# 몸무게: 55
# 키:174
# bmi:18.166204254194742
# 결과:저체중
#
# 이름:가카마
# 몸무게: 141
# 키:133
# bmi:79.71055458194357
# 결과:과체중
#
# 이름:나차타
# 몸무게: 84
# 키:163
# bmi:31.615792841281195
# 결과:과체중
#
# 이름:차파나
# 몸무게: 137
# 키:137
# bmi:72.992700729927
# 결과:과체중
#
# 이름:아사자
# 몸무게: 73
# 키:198
# bmi:18.62054892357923
# 결과:정상체중
#
# 이름:차자라
# 몸무게: 125
# 키:193
# bmi:33.557947864372196
# 결과:과체중
#
# 이름:마차차
# 몸무게: 57
# 키:147
# bmi:26.377898098014718
# 결과:과체중
#
# 이름:카사가
# 몸무게: 67
# 키:153
# bmi:28.621470374642232
# 결과:과체중
#
# 이름:가아마
# 몸무게: 132
# 키:178
# bmi:41.66140638808231
# 결과:과체중
#
# 이름:바나다
# 몸무게: 55
# 키:201
# bmi:13.613524417712437
# 결과:저체중
#
# 이름:자자타
# 몸무게: 51
# 키:158
# bmi:20.429418362441915
# 결과:정상체중
#
# 이름:하라라
# 몸무게: 148
# 키:148
# bmi:67.56756756756756
# 결과:과체중
#
# 이름:바차가
# 몸무게: 58
# 키:185
# bmi:16.946676406135865
# 결과:저체중
#
# 이름:다타타
# 몸무게: 104
# 키:150
# bmi:46.22222222222222
# 결과:과체중
#
# 이름:타하다
# 몸무게: 143
# 키:201
# bmi:35.39516348605233
# 결과:과체중
#
# 이름:다가마
# 몸무게: 116
# 키:199
# bmi:29.29218959117194
# 결과:과체중
#
# 이름:다나다
# 몸무게: 128
# 키:151
# bmi:56.137888689092584
# 결과:과체중
#
# 이름:가가다
# 몸무게: 91
# 키:189
# bmi:25.475210660395845
# 결과:과체중
#
# 이름:가아다
# 몸무게: 137
# 키:190
# bmi:37.95013850415513
# 결과:과체중
#
# 이름:라바파
# 몸무게: 51
# 키:186
# bmi:14.74158862296219
# 결과:저체중
#
# 이름:하하나
# 몸무게: 105
# 키:140
# bmi:53.57142857142858
# 결과:과체중
#
# 이름:바파다
# 몸무게: 69
# 키:145
# bmi:32.81807372175981
# 결과:과체중
#
# 이름:자자나
# 몸무게: 103
# 키:152
# bmi:44.58102493074792
# 결과:과체중
#
# 이름:마하마
# 몸무게: 139
# 키:134
# bmi:77.4114502116284
# 결과:과체중
#
# 이름:카아마
# 몸무게: 74
# 키:144
# bmi:35.68672839506173
# 결과:과체중
#
# 이름:파카다
# 몸무게: 90
# 키:138
# bmi:47.258979206049155
# 결과:과체중
#
# 이름:마카다
# 몸무게: 88
# 키:192
# bmi:23.87152777777778
# 결과:정상체중
#
# 이름:사바자
# 몸무게: 53
# 키:185
# bmi:15.485756026296565
# 결과:저체중
#
# 이름:다타파
# 몸무게: 130
# 키:161
# bmi:50.152386096215416
# 결과:과체중
#
# 이름:카아하
# 몸무게: 125
# 키:174
# bmi:41.28682785044259
# 결과:과체중
#
# 이름:마하마
# 몸무게: 126
# 키:132
# bmi:72.31404958677685
# 결과:과체중
#
# 이름:나사파
# 몸무게: 133
# 키:209
# bmi:30.448020878642893
# 결과:과체중
#
# 이름:라아다
# 몸무게: 145
# 키:188
# bmi:41.025350837483025
# 결과:과체중
#
# 이름:사차하
# 몸무게: 55
# 키:166
# bmi:19.959355494266223
# 결과:정상체중
#
# 이름:나하파
# 몸무게: 110
# 키:153
# bmi:46.99047374941262
# 결과:과체중
#
# 이름:사라카
# 몸무게: 138
# 키:134
# bmi:76.85453330363109
# 결과:과체중
#
# 이름:하자사
# 몸무게: 122
# 키:175
# bmi:39.83673469387755
# 결과:과체중
#
# 이름:마나바
# 몸무게: 144
# 키:183
# bmi:42.9991937651169
# 결과:과체중
#
# 이름:가바타
# 몸무게: 47
# 키:145
# bmi:22.35434007134364
# 결과:정상체중
#
# 이름:하라마
# 몸무게: 121
# 키:195
# bmi:31.821170282708746
# 결과:과체중
#
# 이름:바다바
# 몸무게: 132
# 키:139
# bmi:68.31944516329384
# 결과:과체중
#
# 이름:아라나
# 몸무게: 125
# 키:198
# bmi:31.88450158147128
# 결과:과체중
#
# 이름:파파타
# 몸무게: 137
# 키:167
# bmi:49.123310265696155
# 결과:과체중
#
# 이름:자하마
# 몸무게: 101
# 키:173
# bmi:33.746533462527985
# 결과:과체중
#
# 이름:가하카
# 몸무게: 120
# 키:203
# bmi:29.119852459414215
# 결과:과체중
#
# 이름:마자라
# 몸무게: 76
# 키:185
# bmi:22.205989773557338
# 결과:정상체중
#
# 이름:가파자
# 몸무게: 143
# 키:180
# bmi:44.1358024691358
# 결과:과체중
#
# 이름:라하라
# 몸무게: 71
# 키:152
# bmi:30.730609418282548
# 결과:과체중
#
# 이름:바가나
# 몸무게: 133
# 키:143
# bmi:65.03985524964547
# 결과:과체중
#
# 이름:카차타
# 몸무게: 121
# 키:185
# bmi:35.35427319211102
# 결과:과체중
#
# 이름:카라다
# 몸무게: 93
# 키:140
# bmi:47.44897959183674
# 결과:과체중
#
# 이름:마가라
# 몸무게: 63
# 키:147
# bmi:29.15451895043732
# 결과:과체중
#
# 이름:아하자
# 몸무게: 136
# 키:209
# bmi:31.13481834207093
# 결과:과체중
#
# 이름:아카차
# 몸무게: 123
# 키:196
# bmi:32.01790920449813
# 결과:과체중
#
# 이름:아자차
# 몸무게: 141
# 키:160
# bmi:55.078124999999986
# 결과:과체중
#
# 이름:하차바
# 몸무게: 119
# 키:155
# bmi:49.53173777315296
# 결과:과체중
#
# 이름:나다카
# 몸무게: 103
# 키:152
# bmi:44.58102493074792
# 결과:과체중
#
# 이름:다차타
# 몸무게: 119
# 키:147
# bmi:55.06964690638161
# 결과:과체중
#
# 이름:아하하
# 몸무게: 109
# 키:201
# bmi:26.979530209648285
# 결과:과체중
#
# 이름:타차가
# 몸무게: 119
# 키:178
# bmi:37.558389092286326
# 결과:과체중
#
# 이름:아바파
# 몸무게: 125
# 키:138
# bmi:65.63747111951272
# 결과:과체중
#
# 이름:다하타
# 몸무게: 117
# 키:197
# bmi:30.14764616454946
# 결과:과체중
#
# 이름:하자나
# 몸무게: 63
# 키:177
# bmi:20.109164033323754
# 결과:정상체중
#
# 이름:사카사
# 몸무게: 43
# 키:187
# bmi:12.296605564928935
# 결과:저체중
#
# 이름:차아파
# 몸무게: 67
# 키:206
# bmi:15.788481477990386
# 결과:저체중
#
# 이름:차차가
# 몸무게: 82
# 키:151
# bmi:35.963334941449936
# 결과:과체중
#
# 이름:가나나
# 몸무게: 57
# 키:158
# bmi:22.832879346258608
# 결과:정상체중
#
# 이름:사하다
# 몸무게: 67
# 키:208
# bmi:15.486316568047336
# 결과:저체중
#
# 이름:다타파
# 몸무게: 114
# 키:137
# bmi:60.73845170227502
# 결과:과체중
#
# 이름:자자사
# 몸무게: 44
# 키:169
# bmi:15.405623052414134
# 결과:저체중
#
# 이름:파하라
# 몸무게: 40
# 키:198
# bmi:10.20304050607081
# 결과:저체중
#
# 이름:다카차
# 몸무게: 124
# 키:155
# bmi:51.61290322580645
# 결과:과체중
#
# 이름:타차아
# 몸무게: 88
# 키:174
# bmi:29.065926806711587
# 결과:과체중
#
# 이름:카카파
# 몸무게: 104
# 키:163
# bmi:39.14336256539576
# 결과:과체중
#
# 이름:아타카
# 몸무게: 143
# 키:131
# bmi:83.32847736145911
# 결과:과체중
#
# 이름:하사자
# 몸무게: 68
# 키:167
# bmi:24.38237297859371
# 결과:정상체중
#
# 이름:아다차
# 몸무게: 108
# 키:208
# bmi:24.96301775147929
# 결과:정상체중
#
# 이름:가다마
# 몸무게: 85
# 키:195
# bmi:22.353714661406972
# 결과:정상체중
#
# 이름:마가차
# 몸무게: 115
# 키:144
# bmi:55.45910493827161
# 결과:과체중
#
# 이름:다파라
# 몸무게: 134
# 키:201
# bmi:33.16749585406303
# 결과:과체중
#
# 이름:아파카
# 몸무게: 125
# 키:148
# bmi:57.06720233747261
# 결과:과체중
#
# 이름:차카라
# 몸무게: 59
# 키:134
# bmi:32.85809757184227
# 결과:과체중
#
# 이름:마사마
# 몸무게: 144
# 키:173
# bmi:48.113869491129
# 결과:과체중
#
# 이름:마차자
# 몸무게: 47
# 키:202
# bmi:11.51847858053132
# 결과:저체중
#
# 이름:차자하
# 몸무게: 121
# 키:135
# bmi:66.39231824417008
# 결과:과체중
#
# 이름:나아라
# 몸무게: 119
# 키:167
# bmi:42.669152712538995
# 결과:과체중
#
# 이름:바마자
# 몸무게: 118
# 키:154
# bmi:49.75543936582898
# 결과:과체중
#
# 이름:라차사
# 몸무게: 61
# 키:206
# bmi:14.374587614289755
# 결과:저체중
#
# 이름:바카타
# 몸무게: 133
# 키:203
# bmi:32.27450314251742
# 결과:과체중
#
# 이름:타가카
# 몸무게: 131
# 키:183
# bmi:39.117322105766064
# 결과:과체중
#
# 이름:파카카
# 몸무게: 94
# 키:204
# bmi:22.587466359092655
# 결과:정상체중
#
# 이름:나하사
# 몸무게: 70
# 키:151
# bmi:30.700407876847507
# 결과:과체중
#
# 이름:마바다
# 몸무게: 137
# 키:173
# bmi:45.77500083531023
# 결과:과체중
#
# 이름:라파나
# 몸무게: 145
# 키:177
# bmi:46.28299658463404
# 결과:과체중
#
# 이름:라사나
# 몸무게: 72
# 키:173
# bmi:24.0569347455645
# 결과:정상체중
#
# 이름:차가하
# 몸무게: 58
# 키:163
# bmi:21.829952199932254
# 결과:정상체중
#
# 이름:하차사
# 몸무게: 107
# 키:200
# bmi:26.75
# 결과:과체중
#
# 이름:파하아
# 몸무게: 64
# 키:180
# bmi:19.753086419753085
# 결과:정상체중
#
# 이름:차사바
# 몸무게: 149
# 키:153
# bmi:63.650732624204366
# 결과:과체중
#
# 이름:사자자
# 몸무게: 129
# 키:137
# bmi:68.73035324204805
# 결과:과체중
#
# 이름:파타타
# 몸무게: 85
# 키:202
# bmi:20.831291049897068
# 결과:정상체중
#
# 이름:자카다
# 몸무게: 69
# 키:141
# bmi:34.70650369699714
# 결과:과체중
#
# 이름:나카라
# 몸무게: 73
# 키:183
# bmi:21.798202394816204
# 결과:정상체중
#
# 이름:하파가
# 몸무게: 92
# 키:184
# bmi:27.173913043478258
# 결과:과체중
#
# 이름:다카다
# 몸무게: 55
# 키:134
# bmi:30.63042993985297
# 결과:과체중
#
# 이름:라하다
# 몸무게: 65
# 키:179
# bmi:20.286507911738084
# 결과:정상체중
#
# 이름:하사카
# 몸무게: 85
# 키:175
# bmi:27.755102040816325
# 결과:과체중
#
# 이름:나하마
# 몸무게: 124
# 키:156
# bmi:50.953320184089414
# 결과:과체중
#
# 이름:나카차
# 몸무게: 111
# 키:207
# bmi:25.904921935167685
# 결과:과체중
#
# 이름:사라하
# 몸무게: 142
# 키:185
# bmi:41.49013878743608
# 결과:과체중
#
# 이름:자다사
# 몸무게: 146
# 키:133
# bmi:82.53716999265079
# 결과:과체중
#
# 이름:자나아
# 몸무게: 139
# 키:145
# bmi:66.11177170035671
# 결과:과체중
#
# 이름:카하아
# 몸무게: 50
# 키:171
# bmi:17.09927841045108
# 결과:저체중
#
# 이름:가파차
# 몸무게: 123
# 키:145
# bmi:58.501783590963136
# 결과:과체중
#
# 이름:하하하
# 몸무게: 147
# 키:209
# bmi:33.65307570797373
# 결과:과체중
#
# 이름:자사바
# 몸무게: 67
# 키:131
# bmi:39.042013868655665
# 결과:과체중
#
# 이름:자나다
# 몸무게: 60
# 키:202
# bmi:14.704440741103813
# 결과:저체중
#
# 이름:바나다
# 몸무게: 119
# 키:157
# bmi:48.27782060124143
# 결과:과체중
#
# 이름:하라파
# 몸무게: 47
# 키:167
# bmi:16.85252249991036
# 결과:저체중
#
# 이름:나하바
# 몸무게: 101
# 키:175
# bmi:32.97959183673469
# 결과:과체중
#
# 이름:바나바
# 몸무게: 85
# 키:183
# bmi:25.381468541909282
# 결과:과체중
#
# 이름:카카라
# 몸무게: 99
# 키:184
# bmi:29.24149338374291
# 결과:과체중
#
# 이름:가가하
# 몸무게: 132
# 키:170
# bmi:45.67474048442907
# 결과:과체중
#
# 이름:다하마
# 몸무게: 143
# 키:156
# bmi:58.760683760683754
# 결과:과체중
#
# 이름:마라하
# 몸무게: 129
# 키:160
# bmi:50.39062499999999
# 결과:과체중
#
# 이름:타카아
# 몸무게: 44
# 키:170
# bmi:15.224913494809691
# 결과:저체중
#
# 이름:바차타
# 몸무게: 118
# 키:189
# bmi:33.033789647546264
# 결과:과체중
#
# 이름:사사아
# 몸무게: 82
# 키:191
# bmi:22.47745401715962
# 결과:정상체중
#
# 이름:다파나
# 몸무게: 47
# 키:138
# bmi:24.679689140936784
# 결과:정상체중
#
# 이름:라라가
# 몸무게: 128
# 키:166
# bmi:46.45086369574685
# 결과:과체중
#
# 이름:다라나
# 몸무게: 79
# 키:160
# bmi:30.859374999999993
# 결과:과체중
#
# 이름:나사파
# 몸무게: 52
# 키:208
# bmi:12.019230769230768
# 결과:저체중
#
# 이름:자파아
# 몸무게: 87
# 키:169
# bmi:30.461118308182492
# 결과:과체중
#
# 이름:타사하
# 몸무게: 68
# 키:188
# bmi:19.23947487550928
# 결과:정상체중
#
# 이름:바사사
# 몸무게: 65
# 키:164
# bmi:24.167162403331353
# 결과:정상체중
#
# 이름:차차라
# 몸무게: 149
# 키:135
# bmi:81.75582990397804
# 결과:과체중
#
# 이름:파사자
# 몸무게: 85
# 키:178
# bmi:26.82742078020452
# 결과:과체중
#
# 이름:다하아
# 몸무게: 82
# 키:171
# bmi:28.042816593139772
# 결과:과체중
#
# 이름:다카라
# 몸무게: 135
# 키:151
# bmi:59.20792947677733
# 결과:과체중
#
# 이름:파나바
# 몸무게: 59
# 키:157
# bmi:23.93606231490121
# 결과:정상체중
#
# 이름:차사다
# 몸무게: 77
# 키:148
# bmi:35.15339663988313
# 결과:과체중
#
# 이름:타다차
# 몸무게: 72
# 키:173
# bmi:24.0569347455645
# 결과:정상체중
#
# 이름:다라파
# 몸무게: 77
# 키:162
# bmi:29.340039628105465
# 결과:과체중
#
# 이름:자자사
# 몸무게: 100
# 키:161
# bmi:38.57875853555032
# 결과:과체중
#
# 이름:다파나
# 몸무게: 53
# 키:160
# bmi:20.703124999999996
# 결과:정상체중
#
# 이름:마바타
# 몸무게: 40
# 키:137
# bmi:21.311737439394744
# 결과:정상체중
#
# 이름:사타바
# 몸무게: 90
# 키:208
# bmi:20.802514792899405
# 결과:정상체중
#
# 이름:하차나
# 몸무게: 107
# 키:206
# bmi:25.21444056932793
# 결과:과체중
#
# 이름:바타마
# 몸무게: 137
# 키:156
# bmi:56.295200525969754
# 결과:과체중
#
# 이름:타하카
# 몸무게: 101
# 키:161
# bmi:38.96454612090582
# 결과:과체중
#
# 이름:바카사
# 몸무게: 123
# 키:207
# bmi:28.705454036266893
# 결과:과체중
#
# 이름:다사차
# 몸무게: 108
# 키:207
# bmi:25.204788909892883
# 결과:과체중
#
# 이름:나사바
# 몸무게: 105
# 키:164
# bmi:39.03926234384296
# 결과:과체중
#
# 이름:라나바
# 몸무게: 66
# 키:157
# bmi:26.775934114974238
# 결과:과체중
#
# 이름:다하라
# 몸무게: 56
# 키:167
# bmi:20.07960127648894
# 결과:정상체중
#
# 이름:바타아
# 몸무게: 132
# 키:177
# bmi:42.13348654601168
# 결과:과체중
#
# 이름:자자사
# 몸무게: 119
# 키:192
# bmi:32.28081597222222
# 결과:과체중
#
# 이름:타마파
# 몸무게: 126
# 키:186
# bmi:36.420395421436
# 결과:과체중
#
# 이름:카바라
# 몸무게: 56
# 키:166
# bmi:20.322252866889244
# 결과:정상체중
#
# 이름:파하하
# 몸무게: 70
# 키:149
# bmi:31.530111256249718
# 결과:과체중
#
# 이름:가마하
# 몸무게: 149
# 키:187
# bmi:42.60916812033515
# 결과:과체중
#
# 이름:나타파
# 몸무게: 117
# 키:163
# bmi:44.03628288607023
# 결과:과체중
#
# 이름:마하하
# 몸무게: 90
# 키:132
# bmi:51.652892561983464
# 결과:과체중
#
# 이름:가하라
# 몸무게: 135
# 키:130
# bmi:79.88165680473372
# 결과:과체중
#
# 이름:파바타
# 몸무게: 107
# 키:178
# bmi:33.77098851155157
# 결과:과체중
#
# 이름:파다나
# 몸무게: 143
# 키:138
# bmi:75.08926696072255
# 결과:과체중
#
# 이름:다다카
# 몸무게: 116
# 키:131
# bmi:67.59512848901578
# 결과:과체중
#
# 이름:사파가
# 몸무게: 121
# 키:161
# bmi:46.68029782801589
# 결과:과체중
#
# 이름:나아다
# 몸무게: 139
# 키:141
# bmi:69.91600020119714
# 결과:과체중
#
# 이름:바다가
# 몸무게: 107
# 키:199
# bmi:27.019519709098255
# 결과:과체중
#
# 이름:바파타
# 몸무게: 143
# 키:132
# bmi:82.07070707070706
# 결과:과체중
#
# 이름:나라아
# 몸무게: 45
# 키:198
# bmi:11.47842056932966
# 결과:저체중
#
# 이름:마카바
# 몸무게: 67
# 키:176
# bmi:21.62964876033058
# 결과:정상체중
#
# 이름:바다타
# 몸무게: 108
# 키:185
# bmi:31.55588020452885
# 결과:과체중
#
# 이름:바가라
# 몸무게: 65
# 키:141
# bmi:32.694532468185706
# 결과:과체중
#
# 이름:파가사
# 몸무게: 140
# 키:141
# bmi:70.4189930084
# 결과:과체중
#
# 이름:카카가
# 몸무게: 110
# 키:204
# bmi:26.4321414840446
# 결과:과체중
#
# 이름:차가자
# 몸무게: 59
# 키:168
# bmi:20.904195011337873
# 결과:정상체중
#
# 이름:아자다
# 몸무게: 48
# 키:199
# bmi:12.12090603772632
# 결과:저체중
#
# 이름:가바나
# 몸무게: 125
# 키:131
# bmi:72.83957811316355
# 결과:과체중
#
# 이름:사차사
# 몸무게: 76
# 키:145
# bmi:36.1474435196195
# 결과:과체중
#
# 이름:차자자
# 몸무게: 133
# 키:155
# bmi:55.35900104058272
# 결과:과체중
#
# 이름:가카사
# 몸무게: 97
# 키:145
# bmi:46.13555291319857
# 결과:과체중
#
# 이름:바아마
# 몸무게: 56
# 키:208
# bmi:12.94378698224852
# 결과:저체중
#
# 이름:라자아
# 몸무게: 50
# 키:184
# bmi:14.768431001890358
# 결과:저체중
#
# 이름:가마사
# 몸무게: 110
# 키:151
# bmi:48.243498092188936
# 결과:과체중
#
# 이름:자아사
# 몸무게: 118
# 키:199
# bmi:29.79722734274387
# 결과:과체중
#
# 이름:라나라
# 몸무게: 148
# 키:138
# bmi:77.71476580550306
# 결과:과체중
#
# 이름:타라마
# 몸무게: 65
# 키:185
# bmi:18.991964937910883
# 결과:정상체중
#
# 이름:라카마
# 몸무게: 68
# 키:185
# bmi:19.86851716581446
# 결과:정상체중
#
# 이름:라자자
# 몸무게: 124
# 키:201
# bmi:30.69230959629713
# 결과:과체중
#
# 이름:하카라
# 몸무게: 64
# 키:204
# bmi:15.378700499807767
# 결과:저체중
#
# 이름:카바사
# 몸무게: 119
# 키:168
# bmi:42.16269841269842
# 결과:과체중
#
# 이름:카사라
# 몸무게: 142
# 키:197
# bmi:36.5894509005643
# 결과:과체중
#
# 이름:아마바
# 몸무게: 148
# 키:208
# bmi:34.2085798816568
# 결과:과체중
#
# 이름:가마다
# 몸무게: 136
# 키:187
# bmi:38.891589693728726
# 결과:과체중
#
# 이름:카마타
# 몸무게: 124
# 키:206
# bmi:29.220473183146385
# 결과:과체중
#
# 이름:바가바
# 몸무게: 94
# 키:205
# bmi:22.367638310529447
# 결과:정상체중
#
# 이름:라나마
# 몸무게: 131
# 키:169
# bmi:45.86674136059662
# 결과:과체중
#
# 이름:하타하
# 몸무게: 136
# 키:169
# bmi:47.6173803438255
# 결과:과체중
#
# 이름:가카차
# 몸무게: 140
# 키:181
# bmi:42.7337382863771
# 결과:과체중
#
# 이름:나다라
# 몸무게: 126
# 키:186
# bmi:36.420395421436
# 결과:과체중
#
# 이름:나자라
# 몸무게: 96
# 키:159
# bmi:37.97318144060757
# 결과:과체중
#
# 이름:가하타
# 몸무게: 77
# 키:161
# bmi:29.705644072373747
# 결과:과체중
#
# 이름:아자자
# 몸무게: 65
# 키:158
# bmi:26.037493991347535
# 결과:과체중
#
# 이름:나다바
# 몸무게: 77
# 키:169
# bmi:26.959840341724732
# 결과:과체중
#
# 이름:다다라
# 몸무게: 125
# 키:133
# bmi:70.66538526768048
# 결과:과체중
#
# 이름:다다나
# 몸무게: 144
# 키:150
# bmi:64.0
# 결과:과체중
#
# 이름:차아나
# 몸무게: 96
# 키:151
# bmi:42.103416516819436
# 결과:과체중
#
# 이름:파마아
# 몸무게: 114
# 키:178
# bmi:35.98030551698018
# 결과:과체중
#
# 이름:하타자
# 몸무게: 45
# 키:156
# bmi:18.49112426035503
# 결과:저체중
#
# 이름:하바다
# 몸무게: 90
# 키:157
# bmi:36.51263742951032
# 결과:과체중
#
# 이름:마다바
# 몸무게: 80
# 키:163
# bmi:30.11027889645828
# 결과:과체중
#
# 이름:가차사
# 몸무게: 143
# 키:165
# bmi:52.52525252525253
# 결과:과체중
#
# 이름:하타마
# 몸무게: 135
# 키:192
# bmi:36.62109375
# 결과:과체중
#
# 이름:아타파
# 몸무게: 103
# 키:176
# bmi:33.25154958677686
# 결과:과체중
#
# 이름:가자파
# 몸무게: 149
# 키:158
# bmi:59.685947764781275
# 결과:과체중
#
# 이름:카파하
# 몸무게: 82
# 키:159
# bmi:32.4354258138523
# 결과:과체중
#
# 이름:카자바
# 몸무게: 69
# 키:172
# bmi:23.323418063818284
# 결과:정상체중
#
# 이름:라마차
# 몸무게: 42
# 키:155
# bmi:17.48178980228928
# 결과:저체중
#
# 이름:가카아
# 몸무게: 137
# 키:148
# bmi:62.54565376186998
# 결과:과체중
#
# 이름:하하나
# 몸무게: 61
# 키:173
# bmi:20.381569714992146
# 결과:정상체중
#
# 이름:카차바
# 몸무게: 87
# 키:144
# bmi:41.95601851851852
# 결과:과체중
#
# 이름:파마아
# 몸무게: 79
# 키:151
# bmi:34.64760317529933
# 결과:과체중
#
# 이름:가카마
# 몸무게: 78
# 키:181
# bmi:23.808797045267237
# 결과:정상체중
#
# 이름:하마마
# 몸무게: 52
# 키:171
# bmi:17.783249546869126
# 결과:저체중
#
# 이름:사자카
# 몸무게: 128
# 키:173
# bmi:42.76788399211467
# 결과:과체중
#
# 이름:가차다
# 몸무게: 82
# 키:164
# bmi:30.487804878048784
# 결과:과체중
#
# 이름:타나파
# 몸무게: 144
# 키:172
# bmi:48.67495943753381
# 결과:과체중
#
# 이름:하사나
# 몸무게: 144
# 키:174
# bmi:47.56242568370987
# 결과:과체중
#
# 이름:하바가
# 몸무게: 135
# 키:188
# bmi:38.19601629696695
# 결과:과체중
#
# 이름:아바라
# 몸무게: 119
# 키:130
# bmi:70.41420118343194
# 결과:과체중
#
# 이름:파파나
# 몸무게: 132
# 키:146
# bmi:61.92531431788329
# 결과:과체중
#
# 이름:가나차
# 몸무게: 50
# 키:148
# bmi:22.826880934989045
# 결과:정상체중
#
# 이름:자사바
# 몸무게: 66
# 키:186
# bmi:19.07734998265695
# 결과:정상체중
#
# 이름:차아타
# 몸무게: 112
# 키:186
# bmi:32.37368481905422
# 결과:과체중
#
# 이름:카차타
# 몸무게: 140
# 키:193
# bmi:37.584901608096864
# 결과:과체중
#
# 이름:자하하
# 몸무게: 134
# 키:206
# bmi:31.576962955980772
# 결과:과체중
#
# 이름:파사마
# 몸무게: 103
# 키:182
# bmi:31.095278348025598
# 결과:과체중
#
# 이름:마가하
# 몸무게: 51
# 키:172
# bmi:17.239048134126556
# 결과:저체중
#
# 이름:차바하
# 몸무게: 136
# 키:154
# bmi:57.34525215044696
# 결과:과체중
#
# 이름:카라라
# 몸무게: 83
# 키:155
# bmi:34.54734651404786
# 결과:과체중
#
# 이름:파파아
# 몸무게: 79
# 키:142
# bmi:39.178734378099584
# 결과:과체중
#
# 이름:카마자
# 몸무게: 115
# 키:163
# bmi:43.28352591365878
# 결과:과체중
#
# 이름:바파아
# 몸무게: 65
# 키:131
# bmi:37.876580618845054
# 결과:과체중
#
# 이름:가자아
# 몸무게: 69
# 키:202
# bmi:16.910106852269386
# 결과:저체중
#
# 이름:바바사
# 몸무게: 134
# 키:164
# bmi:49.82153480071387
# 결과:과체중
#
# 이름:바파타
# 몸무게: 61
# 키:206
# bmi:14.374587614289755
# 결과:저체중
#
# 이름:차자아
# 몸무게: 138
# 키:200
# bmi:34.5
# 결과:과체중
#
# 이름:바다카
# 몸무게: 56
# 키:159
# bmi:22.151022507021082
# 결과:정상체중
#
# 이름:파사하
# 몸무게: 125
# 키:162
# bmi:47.62993446121017
# 결과:과체중
#
# 이름:자카자
# 몸무게: 68
# 키:179
# bmi:21.22280827689523
# 결과:정상체중
#
# 이름:가사카
# 몸무게: 44
# 키:165
# bmi:16.161616161616163
# 결과:저체중
#
# 이름:차다아
# 몸무게: 60
# 키:192
# bmi:16.276041666666668
# 결과:저체중
#
# 이름:하파아
# 몸무게: 95
# 키:152
# bmi:41.11842105263158
# 결과:과체중
#
# 이름:카가카
# 몸무게: 129
# 키:164
# bmi:47.96252230814992
# 결과:과체중
#
# 이름:카나아
# 몸무게: 62
# 키:130
# bmi:36.68639053254437
# 결과:과체중
#
# 이름:타라타
# 몸무게: 116
# 키:152
# bmi:50.20775623268698
# 결과:과체중
#
# 이름:가가라
# 몸무게: 143
# 키:177
# bmi:45.644610424845986
# 결과:과체중
#
# 이름:다자바
# 몸무게: 87
# 키:181
# bmi:26.555965935105768
# 결과:과체중
#
# 이름:마마카
# 몸무게: 41
# 키:136
# bmi:22.166955017301035
# 결과:정상체중
#
# 이름:차라바
# 몸무게: 131
# 키:199
# bmi:33.07997272796141
# 결과:과체중
#
# 이름:사라아
# 몸무게: 41
# 키:154
# bmi:17.28790689829651
# 결과:저체중
#
# 이름:하하카
# 몸무게: 60
# 키:183
# bmi:17.916330735465376
# 결과:저체중
#
# 이름:차자라
# 몸무게: 108
# 키:143
# bmi:52.81431854858429
# 결과:과체중
#
# 이름:타아아
# 몸무게: 105
# 키:155
# bmi:43.7044745057232
# 결과:과체중
#
# 이름:라하카
# 몸무게: 70
# 키:172
# bmi:23.661438615467823
# 결과:정상체중
#
# 이름:자바타
# 몸무게: 43
# 키:135
# bmi:23.593964334705074
# 결과:정상체중
#
# 이름:하자나
# 몸무게: 43
# 키:181
# bmi:13.125362473672965
# 결과:저체중
#
# 이름:라라자
# 몸무게: 115
# 키:182
# bmi:34.71802922352373
# 결과:과체중
#
# 이름:바카차
# 몸무게: 98
# 키:146
# bmi:45.974854569337595
# 결과:과체중
#
# 이름:차아타
# 몸무게: 95
# 키:194
# bmi:25.241789775746625
# 결과:과체중
#
# 이름:타차바
# 몸무게: 140
# 키:202
# bmi:34.31036172924223
# 결과:과체중
#
# 이름:차라차
# 몸무게: 100
# 키:177
# bmi:31.91930798940279
# 결과:과체중
#
# 이름:나아자
# 몸무게: 82
# 키:158
# bmi:32.847300112161506
# 결과:과체중
#
# 이름:타나파
# 몸무게: 124
# 키:146
# bmi:58.1722649652843
# 결과:과체중
#
# 이름:다카자
# 몸무게: 121
# 키:137
# bmi:64.4680057541691
# 결과:과체중
#
# 이름:자하타
# 몸무게: 44
# 키:150
# bmi:19.555555555555557
# 결과:정상체중
#
# 이름:가타나
# 몸무게: 95
# 키:194
# bmi:25.241789775746625
# 결과:과체중
#
# 이름:하파아
# 몸무게: 57
# 키:140
# bmi:29.081632653061227
# 결과:과체중
#
# 이름:타자차
# 몸무게: 120
# 키:140
# bmi:61.22448979591837
# 결과:과체중
#
# 이름:파가타
# 몸무게: 71
# 키:139
# bmi:36.7475803529838
# 결과:과체중
#
# 이름:라하나
# 몸무게: 74
# 키:198
# bmi:18.875624936231
# 결과:정상체중
#
# 이름:타가가
# 몸무게: 136
# 키:171
# bmi:46.51003727642694
# 결과:과체중
#
# 이름:다아하
# 몸무게: 66
# 키:151
# bmi:28.946098855313362
# 결과:과체중
#
# 이름:다바카
# 몸무게: 62
# 키:137
# bmi:33.033193031061856
# 결과:과체중
#
# 이름:차하하
# 몸무게: 96
# 키:184
# bmi:28.35538752362949
# 결과:과체중
#
# 이름:마사파
# 몸무게: 124
# 키:176
# bmi:40.03099173553719
# 결과:과체중
#
# 이름:다바다
# 몸무게: 43
# 키:148
# bmi:19.631117604090576
# 결과:정상체중
#
# 이름:타바자
# 몸무게: 119
# 키:184
# bmi:35.14886578449905
# 결과:과체중
#
# 이름:카파차
# 몸무게: 99
# 키:154
# bmi:41.74397031539889
# 결과:과체중
#
# 이름:차가아
# 몸무게: 96
# 키:166
# bmi:34.838147771810135
# 결과:과체중
#
# 이름:라라하
# 몸무게: 84
# 키:197
# bmi:21.64446391300987
# 결과:정상체중
#
# 이름:자타타
# 몸무게: 138
# 키:203
# bmi:33.487830328326346
# 결과:과체중
#
# 이름:타파사
# 몸무게: 139
# 키:154
# bmi:58.610220947883285
# 결과:과체중
#
# 이름:라사하
# 몸무게: 74
# 키:170
# bmi:25.605536332179934
# 결과:과체중
#
# 이름:나마다
# 몸무게: 124
# 키:140
# bmi:63.26530612244899
# 결과:과체중
#
# 이름:파파자
# 몸무게: 63
# 키:169
# bmi:22.058051188683873
# 결과:정상체중
#
# 이름:나타마
# 몸무게: 40
# 키:139
# bmi:20.702862170695102
# 결과:정상체중
#
# 이름:아타마
# 몸무게: 70
# 키:185
# bmi:20.45288531775018
# 결과:정상체중
#
# 이름:사나사
# 몸무게: 127
# 키:206
# bmi:29.927420114996703
# 결과:과체중
#
# 이름:자바아
# 몸무게: 71
# 키:158
# bmi:28.44095497516423
# 결과:과체중
#
# 이름:라아차
# 몸무게: 122
# 키:200
# bmi:30.5
# 결과:과체중
#
# 이름:마다마
# 몸무게: 72
# 키:209
# bmi:16.483139122272846
# 결과:저체중
#
# 이름:바마다
# 몸무게: 143
# 키:188
# bmi:40.459483929379815
# 결과:과체중
#
# 이름:라카바
# 몸무게: 108
# 키:164
# bmi:40.15466983938133
# 결과:과체중
#
# 이름:자바가
# 몸무게: 57
# 키:183
# bmi:17.020514198692105
# 결과:저체중
#
# 이름:자사차
# 몸무게: 83
# 키:150
# bmi:36.888888888888886
# 결과:과체중
#
# 이름:자가가
# 몸무게: 128
# 키:135
# bmi:70.23319615912207
# 결과:과체중
#
# 이름:자하하
# 몸무게: 119
# 키:173
# bmi:39.76076714891911
# 결과:과체중
#
# 이름:마나마
# 몸무게: 56
# 키:137
# bmi:29.836432415152643
# 결과:과체중
#
# 이름:차차바
# 몸무게: 75
# 키:162
# bmi:28.577960676726104
# 결과:과체중
#
# 이름:차카나
# 몸무게: 104
# 키:138
# bmi:54.610375971434586
# 결과:과체중
#
# 이름:사라사
# 몸무게: 54
# 키:168
# bmi:19.13265306122449
# 결과:정상체중
#
# 이름:하카마
# 몸무게: 113
# 키:148
# bmi:51.58875091307524
# 결과:과체중
#
# 이름:사나라
# 몸무게: 142
# 키:156
# bmi:58.34976988823142
# 결과:과체중
#
# 이름:사바바
# 몸무게: 86
# 키:187
# bmi:24.59321112985787
# 결과:정상체중
#
# 이름:가타타
# 몸무게: 135
# 키:140
# bmi:68.87755102040818
# 결과:과체중
#
# 이름:하카아
# 몸무게: 125
# 키:173
# bmi:41.765511711049484
# 결과:과체중
#
# 이름:사하라
# 몸무게: 143
# 키:206
# bmi:33.69780375153172
# 결과:과체중
#
# 이름:차자가
# 몸무게: 74
# 키:192
# bmi:20.07378472222222
# 결과:정상체중
#
# 이름:사카바
# 몸무게: 149
# 키:191
# bmi:40.84317864093638
# 결과:과체중
#
# 이름:바사가
# 몸무게: 120
# 키:174
# bmi:39.63535473642489
# 결과:과체중
#
# 이름:아파사
# 몸무게: 123
# 키:131
# bmi:71.67414486335295
# 결과:과체중
#
# 이름:가사다
# 몸무게: 112
# 키:162
# bmi:42.676421277244316
# 결과:과체중
#
# 이름:자가자
# 몸무게: 143
# 키:166
# bmi:51.89432428509218
# 결과:과체중
#
# 이름:파가나
# 몸무게: 82
# 키:149
# bmi:36.93527318589253
# 결과:과체중
#
# 이름:사사아
# 몸무게: 83
# 키:188
# bmi:23.48347668628339
# 결과:정상체중
#
# 이름:카라카
# 몸무게: 104
# 키:165
# bmi:38.200183654729116
# 결과:과체중
#
# 이름:사바다
# 몸무게: 105
# 키:176
# bmi:33.89721074380165
# 결과:과체중
#
# 이름:파아타
# 몸무게: 135
# 키:159
# bmi:53.39978640085439
# 결과:과체중
#
# 이름:라자가
# 몸무게: 61
# 키:159
# bmi:24.128792373719392
# 결과:정상체중
#
# 이름:카사차
# 몸무게: 93
# 키:191
# bmi:25.492722238973712
# 결과:과체중
#
# 이름:파파아
# 몸무게: 73
# 키:136
# bmi:39.467993079584765
# 결과:과체중
#
# 이름:다하바
# 몸무게: 71
# 키:208
# bmi:16.410872781065088
# 결과:저체중
#
# 이름:카나하
# 몸무게: 74
# 키:180
# bmi:22.839506172839506
# 결과:정상체중
#
# 이름:나아사
# 몸무게: 81
# 키:194
# bmi:21.521947071952386
# 결과:정상체중
#
# 이름:하타다
# 몸무게: 92
# 키:180
# bmi:28.39506172839506
# 결과:과체중
#
# 이름:하카나
# 몸무게: 77
# 키:183
# bmi:22.99262444384723
# 결과:정상체중
#
# 이름:가자가
# 몸무게: 101
# 키:209
# bmi:23.12218126874385
# 결과:정상체중
#
# 이름:라가다
# 몸무게: 55
# 키:130
# bmi:32.54437869822485
# 결과:과체중
#
# 이름:사마타
# 몸무게: 66
# 키:199
# bmi:16.66624580187369
# 결과:저체중
#
# 이름:아자타
# 몸무게: 70
# 키:164
# bmi:26.026174895895306
# 결과:과체중
#
# 이름:마자차
# 몸무게: 45
# 키:173
# bmi:15.035584215977813
# 결과:저체중
#
# 이름:가바카
# 몸무게: 50
# 키:156
# bmi:20.5456936226167
# 결과:정상체중
#
# 이름:파바나
# 몸무게: 74
# 키:172
# bmi:25.013520822065985
# 결과:과체중
#
# 이름:가나라
# 몸무게: 122
# 키:199
# bmi:30.80730284588773
# 결과:과체중
#
# 이름:자카라
# 몸무게: 134
# 키:138
# bmi:70.36336904011763
# 결과:과체중
#
# 이름:하바사
# 몸무게: 94
# 키:177
# bmi:30.00414951003862
# 결과:과체중
#
# 이름:라바마
# 몸무게: 115
# 키:190
# bmi:31.855955678670362
# 결과:과체중
#
# 이름:사사카
# 몸무게: 139
# 키:179
# bmi:43.381916918947596
# 결과:과체중
#
# 이름:마가다
# 몸무게: 112
# 키:145
# bmi:53.269916765755056
# 결과:과체중
#
# 이름:카자바
# 몸무게: 112
# 키:192
# bmi:30.381944444444446
# 결과:과체중
#
# 이름:파바라
# 몸무게: 78
# 키:135
# bmi:42.798353909465014
# 결과:과체중
#
# 이름:마자타
# 몸무게: 108
# 키:179
# bmi:33.70681314565713
# 결과:과체중
#
# 이름:마사타
# 몸무게: 45
# 키:168
# bmi:15.94387755102041
# 결과:저체중
#
# 이름:하나아
# 몸무게: 59
# 키:204
# bmi:14.177239523260285
# 결과:저체중
#
# 이름:라자차
# 몸무게: 102
# 키:157
# bmi:41.380989086778364
# 결과:과체중
#
# 이름:마다마
# 몸무게: 46
# 키:138
# bmi:24.15458937198068
# 결과:정상체중
#
# 이름:나아하
# 몸무게: 67
# 키:169
# bmi:23.458562375266975
# 결과:정상체중
#
# 이름:가타차
# 몸무게: 132
# 키:172
# bmi:44.61871281773932
# 결과:과체중
#
# 이름:아파사
# 몸무게: 133
# 키:156
# bmi:54.651545036160414
# 결과:과체중
#
# 이름:나자나
# 몸무게: 90
# 키:175
# bmi:29.387755102040817
# 결과:과체중
#
# 이름:자차카
# 몸무게: 115
# 키:208
# bmi:26.58099112426035
# 결과:과체중
#
# 이름:파라나
# 몸무게: 82
# 키:176
# bmi:26.47210743801653
# 결과:과체중
#
# 이름:가다라
# 몸무게: 63
# 키:156
# bmi:25.88757396449704
# 결과:과체중
#
# 이름:자다마
# 몸무게: 87
# 키:196
# bmi:22.646813827571847
# 결과:정상체중
#
# 이름:파나나
# 몸무게: 44
# 키:203
# bmi:10.677279235118545
# 결과:저체중
#
# 이름:가나하
# 몸무게: 54
# 키:156
# bmi:22.189349112426033
# 결과:정상체중
#
# 이름:하사마
# 몸무게: 76
# 키:200
# bmi:19.0
# 결과:정상체중
#
# 이름:카가가
# 몸무게: 141
# 키:165
# bmi:51.79063360881543
# 결과:과체중
#
# 이름:타마하
# 몸무게: 108
# 키:165
# bmi:39.66942148760331
# 결과:과체중
#
# 이름:카자사
# 몸무게: 59
# 키:195
# bmi:15.516107823800132
# 결과:저체중
#
# 이름:마마차
# 몸무게: 120
# 키:200
# bmi:30.0
# 결과:과체중
#
# 이름:타아카
# 몸무게: 88
# 키:186
# bmi:25.4364666435426
# 결과:과체중
#
# 이름:다카하
# 몸무게: 108
# 키:195
# bmi:28.40236686390533
# 결과:과체중
#
# 이름:다자타
# 몸무게: 60
# 키:155
# bmi:24.97398543184183
# 결과:정상체중
#
# 이름:차하차
# 몸무게: 131
# 키:156
# bmi:53.82971729125575
# 결과:과체중
#
# 이름:타자나
# 몸무게: 78
# 키:136
# bmi:42.1712802768166
# 결과:과체중
#
# 이름:가하사
# 몸무게: 62
# 키:169
# bmi:21.707923392038097
# 결과:정상체중
#
# 이름:라차마
# 몸무게: 133
# 키:138
# bmi:69.83826927116154
# 결과:과체중
#
# 이름:다다나
# 몸무게: 136
# 키:166
# bmi:49.35404267673103
# 결과:과체중
#
# 이름:라하마
# 몸무게: 40
# 키:153
# bmi:17.087444999786406
# 결과:저체중
#
# 이름:나라타
# 몸무게: 61
# 키:182
# bmi:18.41565028378215
# 결과:저체중
#
# 이름:타다마
# 몸무게: 60
# 키:157
# bmi:24.341758286340216
# 결과:정상체중
#
# 이름:사파마
# 몸무게: 60
# 키:143
# bmi:29.34128808254683
# 결과:과체중
#
# 이름:타나마
# 몸무게: 116
# 키:201
# bmi:28.712160590084412
# 결과:과체중
#
# 이름:하마가
# 몸무게: 68
# 키:152
# bmi:29.43213296398892
# 결과:과체중
#
# 이름:가마가
# 몸무게: 91
# 키:165
# bmi:33.425160697887975
# 결과:과체중
#
# 이름:하파타
# 몸무게: 145
# 키:137
# bmi:77.25504821780595
# 결과:과체중
#
# 이름:라하바
# 몸무게: 119
# 키:206
# bmi:28.042228296729192
# 결과:과체중
#
# 이름:아나마
# 몸무게: 131
# 키:133
# bmi:74.05732376052913
# 결과:과체중
#
# 이름:나하타
# 몸무게: 118
# 키:166
# bmi:42.821889969516626
# 결과:과체중
#
# 이름:하파카
# 몸무게: 59
# 키:152
# bmi:25.536703601108034
# 결과:과체중
#
# 이름:타나파
# 몸무게: 136
# 키:137
# bmi:72.45990729394212
# 결과:과체중
#
# 이름:마파라
# 몸무게: 59
# 키:160
# bmi:23.046874999999996
# 결과:정상체중
#
# 이름:파파바
# 몸무게: 92
# 키:133
# bmi:52.009723557012826
# 결과:과체중
#
# 이름:아아나
# 몸무게: 106
# 키:206
# bmi:24.97879159204449
# 결과:정상체중
#
# 이름:다사사
# 몸무게: 61
# 키:139
# bmi:31.57186481031003
# 결과:과체중
#
# 이름:마나사
# 몸무게: 114
# 키:194
# bmi:30.290147730895953
# 결과:과체중
#
# 이름:파아라
# 몸무게: 94
# 키:154
# bmi:39.63568898633834
# 결과:과체중
#
# 이름:라가나
# 몸무게: 128
# 키:191
# bmi:35.08675749020038
# 결과:과체중
#
# 이름:아카파
# 몸무게: 141
# 키:167
# bmi:50.55756749973108
# 결과:과체중
#
# 이름:차하사
# 몸무게: 90
# 키:153
# bmi:38.446751249519416
# 결과:과체중
#
# 이름:라가아
# 몸무게: 127
# 키:131
# bmi:74.00501136297417
# 결과:과체중
#
# 이름:하차하
# 몸무게: 87
# 키:202
# bmi:21.32143907460053
# 결과:정상체중
#
# 이름:라차바
# 몸무게: 143
# 키:153
# bmi:61.087615874236405
# 결과:과체중
#
# 이름:아사바
# 몸무게: 126
# 키:148
# bmi:57.52373995617239
# 결과:과체중
#
# 이름:아바하
# 몸무게: 98
# 키:176
# bmi:31.63739669421488
# 결과:과체중
#
# 이름:나마파
# 몸무게: 68
# 키:158
# bmi:27.239224483255885
# 결과:과체중
#
# 이름:하사타
# 몸무게: 110
# 키:141
# bmi:55.329208792314276
# 결과:과체중
#
# 이름:하하차
# 몸무게: 66
# 키:207
# bmi:15.402926556045651
# 결과:저체중
#
# 이름:나카마
# 몸무게: 113
# 키:195
# bmi:29.717291255752794
# 결과:과체중
#
# 이름:나다파
# 몸무게: 110
# 키:141
# bmi:55.329208792314276
# 결과:과체중
#
# 이름:파사마
# 몸무게: 98
# 키:171
# bmi:33.51458568448412
# 결과:과체중
#
# 이름:나아사
# 몸무게: 58
# 키:192
# bmi:15.733506944444445
# 결과:저체중
#
# 이름:다카자
# 몸무게: 124
# 키:197
# bmi:31.951351490633616
# 결과:과체중
#
# 이름:차라자
# 몸무게: 128
# 키:165
# bmi:47.01561065197429
# 결과:과체중
#
# 이름:파가파
# 몸무게: 141
# 키:197
# bmi:36.33177871112371
# 결과:과체중
#
# 이름:마자아
# 몸무게: 44
# 키:201
# bmi:10.89081953416995
# 결과:저체중
#
# 이름:마가바
# 몸무게: 97
# 키:138
# bmi:50.93467758874187
# 결과:과체중
#
# 이름:나하타
# 몸무게: 146
# 키:164
# bmi:54.28316478286735
# 결과:과체중
#
# 이름:라자다
# 몸무게: 144
# 키:203
# bmi:34.94382295129706
# 결과:과체중
#
# 이름:자하타
# 몸무게: 90
# 키:200
# bmi:22.5
# 결과:정상체중
#
# 이름:다아파
# 몸무게: 77
# 키:197
# bmi:19.840758586925713
# 결과:정상체중
#
# 이름:사카사
# 몸무게: 124
# 키:150
# bmi:55.111111111111114
# 결과:과체중
#
# 이름:하차바
# 몸무게: 103
# 키:206
# bmi:24.271844660194176
# 결과:정상체중
#
# 이름:파차아
# 몸무게: 76
# 키:162
# bmi:28.959000152415786
# 결과:과체중
#
# 이름:파아바
# 몸무게: 50
# 키:158
# bmi:20.028841531805796
# 결과:정상체중
#
# 이름:아아하
# 몸무게: 68
# 키:198
# bmi:17.345168860320378
# 결과:저체중
#
# 이름:사다사
# 몸무게: 137
# 키:205
# bmi:32.59964306960143
# 결과:과체중
#
# 이름:가나사
# 몸무게: 128
# 키:141
# bmi:64.38307932196571
# 결과:과체중
#
# 이름:가사다
# 몸무게: 57
# 키:164
# bmi:21.192742415229034
# 결과:정상체중
#
# 이름:다라가
# 몸무게: 48
# 키:209
# bmi:10.988759414848563
# 결과:저체중
#
# 이름:나자하
# 몸무게: 104
# 키:140
# bmi:53.061224489795926
# 결과:과체중
#
# 이름:사나하
# 몸무게: 142
# 키:131
# bmi:82.7457607365538
# 결과:과체중
#
# 이름:나다자
# 몸무게: 140
# 키:208
# bmi:32.3594674556213
# 결과:과체중
#
# 이름:나나차
# 몸무게: 75
# 키:148
# bmi:34.240321402483566
# 결과:과체중
#
# 이름:자마카
# 몸무게: 51
# 키:156
# bmi:20.956607495069033
# 결과:정상체중
#
# 이름:아다타
# 몸무게: 106
# 키:177
# bmi:33.834466468766955
# 결과:과체중
#
# 이름:카가마
# 몸무게: 129
# 키:168
# bmi:45.70578231292518
# 결과:과체중
#
# 이름:나카아
# 몸무게: 110
# 키:195
# bmi:28.928336620644316
# 결과:과체중
#
# 이름:바타다
# 몸무게: 98
# 키:182
# bmi:29.585798816568044
# 결과:과체중
#
# 이름:아라사
# 몸무게: 148
# 키:130
# bmi:87.57396449704142
# 결과:과체중
#
# 이름:마하파
# 몸무게: 94
# 키:186
# bmi:27.170771187420506
# 결과:과체중
#
# 이름:가사자
# 몸무게: 60
# 키:147
# bmi:27.76620852422602
# 결과:과체중
#
# 이름:사카마
# 몸무게: 74
# 키:208
# bmi:17.1042899408284
# 결과:저체중
#
# 이름:카타자
# 몸무게: 62
# 키:181
# bmi:18.924941241109856
# 결과:정상체중
#
# 이름:카파마
# 몸무게: 101
# 키:181
# bmi:30.829339763743477
# 결과:과체중
#
# 이름:차아마
# 몸무게: 48
# 키:184
# bmi:14.177693761814744
# 결과:저체중
#
# 이름:나가사
# 몸무게: 41
# 키:162
# bmi:15.622618503276936
# 결과:저체중
#
# 이름:다파가
# 몸무게: 82
# 키:156
# bmi:33.694937541091385
# 결과:과체중
#
# 이름:자다카
# 몸무게: 97
# 키:142
# bmi:48.105534616147594
# 결과:과체중
#
# 이름:사자라
# 몸무게: 96
# 키:132
# bmi:55.09641873278236
# 결과:과체중
#
# 이름:다파파
# 몸무게: 47
# 키:141
# bmi:23.640661938534283
# 결과:정상체중
#
# 이름:차타자
# 몸무게: 99
# 키:195
# bmi:26.035502958579883
# 결과:과체중
#
# 이름:하나사
# 몸무게: 105
# 키:149
# bmi:47.29516688437458
# 결과:과체중
#
# 이름:타나라
# 몸무게: 72
# 키:172
# bmi:24.337479718766904
# 결과:정상체중
#
# 이름:마나사
# 몸무게: 96
# 키:192
# bmi:26.041666666666668
# 결과:과체중
#
# 이름:타타바
# 몸무게: 98
# 키:136
# bmi:52.98442906574393
# 결과:과체중
#
# 이름:하하사
# 몸무게: 62
# 키:180
# bmi:19.1358024691358
# 결과:정상체중
#
# 이름:다타마
# 몸무게: 88
# 키:176
# bmi:28.40909090909091
# 결과:과체중
#
# 이름:가차타
# 몸무게: 41
# 키:154
# bmi:17.28790689829651
# 결과:저체중
#
# 이름:차타사
# 몸무게: 80
# 키:189
# bmi:22.395789591556788
# 결과:정상체중
#
# 이름:바차가
# 몸무게: 147
# 키:150
# bmi:65.33333333333333
# 결과:과체중
#
# 이름:가아자
# 몸무게: 111
# 키:173
# bmi:37.08777439941194
# 결과:과체중
#
# 이름:아자자
# 몸무게: 92
# 키:169
# bmi:32.21175729141137
# 결과:과체중
#
# 이름:다가카
# 몸무게: 112
# 키:208
# bmi:25.88757396449704
# 결과:과체중
#
# 이름:사다타
# 몸무게: 93
# 키:179
# bmi:29.025311319871417
# 결과:과체중
#
# 이름:차라카
# 몸무게: 102
# 키:202
# bmi:24.997549259876482
# 결과:정상체중
#
# 이름:사카가
# 몸무게: 48
# 키:208
# bmi:11.094674556213016
# 결과:저체중
#
# 이름:사카자
# 몸무게: 79
# 키:133
# bmi:44.66052348917406
# 결과:과체중
#
# 이름:다하가
# 몸무게: 41
# 키:148
# bmi:18.718042366691016
# 결과:정상체중
#
# 이름:마나나
# 몸무게: 81
# 키:205
# bmi:19.274241522903036
# 결과:정상체중
#
# 이름:사차사
# 몸무게: 50
# 키:140
# bmi:25.510204081632658
# 결과:과체중
#
# 이름:하마하
# 몸무게: 71
# 키:208
# bmi:16.410872781065088
# 결과:저체중
#
# 이름:하가차
# 몸무게: 49
# 키:175
# bmi:16.0
# 결과:저체중
#
# 이름:파파사
# 몸무게: 87
# 키:131
# bmi:50.69634636676184
# 결과:과체중
#
# 이름:마라사
# 몸무게: 59
# 키:144
# bmi:28.452932098765434
# 결과:과체중
#
# 이름:차카가
# 몸무게: 88
# 키:148
# bmi:40.17531044558072
# 결과:과체중
#
# 이름:다라차
# 몸무게: 125
# 키:206
# bmi:29.456122160429825
# 결과:과체중
#
# 이름:타자사
# 몸무게: 122
# 키:164
# bmi:45.35990481856039
# 결과:과체중
#
# 이름:파사하
# 몸무게: 51
# 키:147
# bmi:23.601277245592115
# 결과:정상체중
#
# 이름:마하타
# 몸무게: 99
# 키:199
# bmi:24.999368702810536
# 결과:정상체중
#
# 이름:가아라
# 몸무게: 108
# 키:155
# bmi:44.95317377731529
# 결과:과체중
#
# 이름:가나가
# 몸무게: 50
# 키:195
# bmi:13.149243918474689
# 결과:저체중
#
# 이름:자파마
# 몸무게: 108
# 키:178
# bmi:34.086605226612804
# 결과:과체중
#
# 이름:아자타
# 몸무게: 90
# 키:164
# bmi:33.462224866151104
# 결과:과체중
#
# 이름:자차마
# 몸무게: 79
# 키:203
# bmi:19.170569535781024
# 결과:정상체중

# %%
# 리스트 함수를 딕셔너리에서 사용
books = [{"제목":"A",
          "가격":10000},
         {"제목":"B",
          "가격":20000},
         {"제목":"C",
          "가격":30000}]
def price(book):
  return book["가격"]
print(min(books,key = price))
print(max(books,key = price))
# Out:
# {'제목': 'A', '가격': 10000}
# {'제목': 'C', '가격': 30000}

# %%
# 람다로 변경
books = [{"제목":"A",
          "가격":10000},
         {"제목":"B",
          "가격":20000},
         {"제목":"C",
          "가격":30000}]
print(min(books,key = lambda book: book["가격"]))
print(max(books,key = lambda book: book["가격"]))
# Out:
# {'제목': 'A', '가격': 10000}
# {'제목': 'C', '가격': 30000}

# %%
# 리스트 정렬
# 오름차순
a = [1,25,34,7,15]
a.sort()
print(a)
# Out:
# [1, 7, 15, 25, 34]

# %%
# 리스트 정렬
# 내림차순
a = [1,25,34,7,15]
a.sort(reverse=True)
print(a)
# Out:
# [34, 25, 15, 7, 1]

# %%
# sort 적용
books = [{"제목":"A",
          "가격":10000},
         {"제목":"B",
          "가격":20000},
         {"제목":"C",
          "가격":30000}]
books.sort(key = lambda book: book["가격"],reverse= True )
print(books)
# Out:
# [{'제목': 'C', '가격': 30000}, {'제목': 'B', '가격': 20000}, {'제목': 'A', '가격': 10000}]

# %%
numbers = [1,2,3,4,5,6]

# map 함수를 사용하여 numbers 리스트의 원소들을 문자열로 변환
# map 함수는 원소들을 지정된 함수(str 함수)에 적용하여 새로운 리스트를 반환
# 하지만 map 함수는 iterator 객체를 반환하므로, 바로 출력하면 주소 값이 출력됨
print(map(str,numbers))  # 출력 결과: <map object at [주소값]>

# map 함수를 사용하여 numbers 리스트의 원소들을 문자열로 변환하여 새로운 리스트를 생성
# list 함수를 사용하여 iterator 객체를 리스트로 변환하여 출력
print(list(map(str,numbers)))  # 출력 결과: ['1', '2', '3', '4', '5', '6']

# map 함수를 사용하여 numbers 리스트의 원소들을 문자열로 변환하고, "::" 문자열로 연결하여 출력
# join 함수를 사용하여 리스트의 원소들을 지정된 문자열로 연결
print("::".join(map(str,numbers)))  # 출력 결과: '1::2::3::4::5::6'
# Out:
# <map object at 0x7f8ee43f1af0>
# ['1', '2', '3', '4', '5', '6']
# 1::2::3::4::5::6

# %%
# 확인 문제 1번 352p
numbers = list(range(1,10+1))


print("# 홀수만 추출하기")
print(list(filter(lambda x: x%2 != 0,numbers)))
print()

print("# 3이상, 7 미만 추출하기")
print(list(filter(lambda x: 3<=x<7,numbers)))
print()

print("# 제곱하기")
print(list(filter(lambda x: x**2<50,numbers)))
# Out:
# # 홀수만 추출하기
# [1, 3, 5, 7, 9]
#
# # 3이상, 7 미만 추출하기
# [3, 4, 5, 6]
#
# # 제곱하기
# [1, 2, 3, 4, 5, 6, 7]

# %%
# 도전 문제 1
def hanoi(n, from_tower, to_tower, aux_tower):
    if n == 1:
        print(from_tower, "->", to_tower) # 원판이 1개일 경우에는 그냥 직접 옮김
    else:
        hanoi(n-1, from_tower, aux_tower, to_tower) # 원판 n-1개를 보조 기둥으로 옮김
        print(from_tower, "->", to_tower) # 원판 n을 목적 기둥으로 옮김
        hanoi(n-1, aux_tower, to_tower, from_tower) # 보조 기둥에 있는 n-1개의 원판을 목적 기둥으로 옮김

n = int(input("원판의 개수를 입력해주세요:"))  # 원판 개수 입력 받음
hanoi(n, "A", "B", "C")  # A 기둥에서 C 기둥으로 원판을 옮기는 과정 출력
# Out:
# 원판의 개수를 입력해주세요:2
# A -> C
# A -> B
# C -> B

# %%
# 도전 문제 2
def hanoi(n, from_tower, to_tower, aux_tower):
    if n == 1:
        print(from_tower, "->", to_tower) # 원판이 1개일 경우에는 그냥 직접 옮김
        return 1 # 이동 횟수 1 추가
    else:
        count = 0 # 이동 횟수를 카운트하는 변수
        count += hanoi(n-1, from_tower, aux_tower, to_tower) # 원판 n-1개를 보조 기둥으로 옮기는 과정의 이동 횟수를 추가
        print(from_tower, "->", to_tower) # 원판 n을 목적 기둥으로 옮김
        count += 1 # 이동 횟수 1 추가
        count += hanoi(n-1, aux_tower, to_tower, from_tower) # 보조 기둥에 있는 n-1개의 원판을 목적 기둥으로 옮기는 과정의 이동 횟수를 추가
        return count # 전체 이동 횟수 반환

n = int(input("원판의 개수를 입력해주세요:"))  # 원판 개수 입력 받음
total_count = hanoi(n, "A", "B", "C")  # A 기둥에서 C 기둥으로 원판을 옮기는 과정 출력 및 이동 횟수 반환
print("총 이동 횟수:", total_count) # 총 이동 횟수 출력
# Out:
# 원판의 개수를 입력해주세요:2
# A -> C
# A -> B
# C -> B
# 총 이동 횟수: 3

# %%
import matplotlib.pyplot as plt

# 원판을 옮기는 함수
def hanoi(n, from_tower, to_tower, aux_tower):
    if n == 1:
        print(from_tower, "->", to_tower)
        plt.plot([from_tower, to_tower], [0, 1], 'ro-') # 이동 경로를 시각화
    else:
        hanoi(n-1, from_tower, aux_tower, to_tower)
        print(from_tower, "->", to_tower)
        plt.plot([from_tower, to_tower], [0, 1], 'ro-') # 이동 경로를 시각화
        hanoi(n-1, aux_tower, to_tower, from_tower)

# 원판 개수 입력 받음
n = int(input("원판의 개수를 입력해주세요:"))

# 그래프 설정
fig = plt.figure(figsize=(5, 5))
plt.axis('off')
plt.xlim([-1, 3])
plt.ylim([-0.2, 1.2])

# 타이틀
plt.title(f'Hanoi Tower (n={n})')

# 초기 위치 표시
for i in range(n):
    plt.text(i, 0, str(i+1), ha='center', va='center')

# 하노이 탑 알고리즘 실행 및 시각화
hanoi(n, 'A', 'C', 'B')

# 그래프 출력
plt.show()
# Out:
# 원판의 개수를 입력해주세요:1
# A -> C

# %%
# 구문 오류
print("안녕 파이썬 할만하니)
# Out:
#   File "<ipython-input-169-794831a305a5>", line 2
#     print("안녕 파이썬 할만하니)
#                        ^
# SyntaxError: EOL while scanning string literal

# %%
# 예외, 런타임오류
print("리스트 불러보자")
list_z[0]
# Out:
# 리스트 불러보자
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-171-25648f9c60ea> in <cell line: 3>()
#       1 # 예외, 런타임오류
#       2 print("리스트 불러보자")
# ----> 3 list_z[0]
#       4
#
# NameError: name 'list_z' is not defined

# %%
# 오류 수정
print("리스트 불러보자")
list_z = [1,2,3]
list_z[0]
# Out:
# 리스트 불러보자
# 1

# %%
# 예외 상황 만들기 - 숫자로 변환할 수 없는 값을 입력한 경우
no = input("정수 입력>")
no = int(no)
print("원의 반지름", no)
print("원의 둘레", 2*3.14*no)
print("원의 넓이", 3.14*no*no)
# Out:
# 정수 입력>2
# 원의 반지름 2
# 원의 둘레 12.56
# 원의 넓이 12.56

# %%
# 조건문으로 예외 처리
no = input("정수 입력>")
if no.isdigit(): # 숫자로 변환할 수 있는 값을 입력한 경우
  no = int(no)
  print("원의 반지름", no)
  print("원의 둘레", 2*3.14*no)
  print("원의 넓이", 3.14*no*no)
else: # 나머지 = 숫자로 변환할 수 있는 값을 입력하지 않은 경우
  print("숫자가 입력되지 않았습니다. 정수를 입력하세요")
# Out:
# 정수 입력>ㅁㄴㅇㅁ
# 숫자가 입력되지 않았습니다. 정수를 입력하세요

# %%
# try except 구문으로 예외 처리
try:
  no = input("정수 입력>")
  no = int(no)
  print("원의 반지름", no)
  print("원의 둘레", 2*3.14*no)
  print("원의 넓이", 3.14*no*no)
except:
  print("숫자가 아닙니다. 정수만 입력해주세요")
# Out:
# 정수 입력>2
# 원의 반지름 2
# 원의 둘레 12.56
# 원의 넓이 12.56

# %%
# try except 구문으로 예외 처리
try:
  no = input("정수 입력>")
  no = int(no)
  print("원의 반지름", no)
  print("원의 둘레", 2*3.14*no)
  print("원의 넓이", 3.14*no*no)
except:
  pass
# Out:
# 정수 입력>2
# 원의 반지름 2
# 원의 둘레 12.56
# 원의 넓이 12.56

# %%
# try except else 구문으로 예외 처리
try:
  no = input("정수 입력>")
  no = int(no)
except:
  print("정수를 입력해주시겠어요")
else:
  print("원의 반지름", no)
  print("원의 둘레", 2*3.14*no)
  print("원의 넓이", 3.14*no*no)
# Out:
# 정수 입력>4
# 원의 반지름 4
# 원의 둘레 25.12
# 원의 넓이 50.24

# %%
# try except else finally 구문으로 예외처리
try:
  no = input("정수 입력>")
  no = int(no)
except:
  print("정수를 입력해주시겠어요")
else:
  print("원의 반지름", no)
  print("원의 둘레", 2*3.14*no)
  print("원의 넓이", 3.14*no*no)
finally:
  print("프로그램은 어떻게든 종료가 되었어요")
